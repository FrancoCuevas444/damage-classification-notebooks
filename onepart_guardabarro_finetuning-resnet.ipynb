# %% [markdown]
# ## Introducción
#
# Entrenamiento de modelo preentrenado para resolver el problema de predecir el ángulo del auto en base a la imagen.
#
# Fuertemente basado en:
# - https://towardsdatascience.com/a-practical-example-in-transfer-learning-with-pytorch-846bb835f2db
# - https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

# %% [markdown]
# ## Imports

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.datasets as datasets
import torchvision.models as models
import torchvision.transforms as transforms
from torchmetrics import MetricCollection, Accuracy, Precision, Recall, F1, ConfusionMatrix
import pandas as pd
import sklearn
from torch.utils.tensorboard import SummaryWriter

from datetime import datetime
import os

import importlib
import training_helper
from dataset_modules.one_part_dataset import OnePartDataset
import metrics_helper

importlib.reload(training_helper)
importlib.reload(metrics_helper)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_12435/2761867636.py in <module>
#      16 import importlib
#      17 import training_helper
# ---> 18 from dataset_modules.one_part_dataset import OnePartDataset
#      19 import metrics_helper
#      20
#
# ~/dataset_modules/one_part_dataset.py in <module>
#       3 from PIL import Image
#       4 from torchvision import transforms
# ----> 5 import common
#       6 import json
#       7
#
# ModuleNotFoundError: No module named 'common'

# %% [markdown]
# ## Variables

# %%
MODEL_NAME = "one_part_model"
EXPERIMENT_NAME = "resnet50_guardabarrodelder_fine_tuning-final-withoutrepair"
FEATURE_EXTRACTION = False
parte = "Guardabarro Delantero Derecho"

device_string = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(device_string)

if device_string == "cuda":
    print("Usando GPU!")

os.makedirs("./trained_models/{}/{}/".format(MODEL_NAME, EXPERIMENT_NAME), exist_ok=True)
# Out:
# Usando GPU!

# %% [markdown]
# ## Dataset
#
# Se crea un dataset de tipo `ImageFolder` que se toma de la carpeta `dataset`, donde cada subcarpeta es una de las categorías a entrenar.
#
# Automáticamente mapea categorías a números `dataset.class_to_idx`.
#
# Finalmente se hace el split en train y test en 80/20.

# %%
print("start to load dataset")
dataset = OnePartDataset(
    parte,
    transform=transforms.Compose([
        transforms.ColorJitter(0.1, 0.1, 0.1, 0.1),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    root='/scratch/franco.cuevas/imgs/',
    preload=True
)
print("finish to load dataset")

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size], generator=torch.Generator().manual_seed(42))

classes = dataset.classes

dataset_sizes = {
    'train': len(train_dataset),
    'test': len(test_dataset)
}

print("#TRAIN {} #TEST {}".format(dataset_sizes["train"], dataset_sizes["test"]))
# Out:
# start to load dataset
# ----- CLASS DISTRIBUTION -----
# Class: no_guardabarro_delantero_derecho, #1014, 60.90%
# Class: guardabarro_delantero_derecho_sano, #454, 27.27%
# Class: guardabarro_delantero_derecho_roto, #197, 11.83%
# finish to load dataset
# #TRAIN 1332 #TEST 333

# %% [markdown]
# ## Loaders
# Luego, se crean loaders para cada uno de los conjuntos. Los loaders permiten procesar los datos de a batches.

# %%
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True,
    num_workers=0
)

test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=16,
    shuffle=True,
    num_workers=0
)

dataloaders = {
    'train': train_loader,
    'test': test_loader
}

# %% [markdown]
# ## Entrenamiento
#
# En este step se carga el modelo pre-entrenado. Para este ejemplo se utiliza el modelo alexnet por su simplicidad.

# %% [markdown]
# #### ¿Finetuning o Feature extraction?
#
# - **Finetuning:** Consiste en incializar la red con los pesos pre-entrenados, y re-entrenar toda la red (ajustar los parámetros de todas las capas) con el dataset custom.
# - **Feature extraction:** La diferencia con lo anterior es que se congelan las capas convolucionales, de modo que el entrenamiento no las cambie con nuestros datos.
#
# En ambos casos pisamos la capa de **clasificador** por una capa nueva con 8 categorías, porque el modelo pre-entrenado tiene 1000 labels.

# %%
model = models.resnet50(pretrained=True)
NUM_CLASSES = len(classes)

if FEATURE_EXTRACTION:
    for param in model.parameters():
        param.requires_grad = False

model.fc = torch.nn.Linear(2048, NUM_CLASSES)
model = model.to(device)

# Tensorboard metrics writer
writer = SummaryWriter(log_dir='./trained_models/{}/tensorboard/{}'.format(MODEL_NAME, EXPERIMENT_NAME + '-' + datetime.now().strftime("%Y%m%d-%H%M%S")))

# Función de error
criterion = F.cross_entropy

# Optimizador
parameters_to_update = model.parameters()

if FEATURE_EXTRACTION:
    parameters_to_update = model.fc.parameters()

optimizer = optim.SGD(parameters_to_update, lr=0.001)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=3, bias=True)
# )

# %%
model = training_helper.train_model(
    model, 
    criterion, 
    optimizer, 
    dataloaders, 
    dataset_sizes, 
    device, 
    writer, 
    NUM_CLASSES,
    'trained_models/{}/{}'.format(MODEL_NAME, EXPERIMENT_NAME),
    main_metric='macro_f1', 
    num_epochs=30
)
# Out:
# Epoch 0/29
# ----------
# train Loss: 0.9235 Main metric (macro_f1): 0.3319 Time: 9.75s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.9234723971412705
# Micro Accuracy 0.5998498201370239
# Macro Accuracy 0.331939697265625
# Macro Precision 0.27963268756866455
# Macro Recall 0.331939697265625
# Macro F1 0.331939697265625
#
# test Loss: 0.8805 Main metric (macro_f1): 0.3333 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8804948956400782
# Micro Accuracy 0.6126126050949097
# Macro Accuracy 0.3333333432674408
# Macro Precision 0.20420420169830322
# Macro Recall 0.3333333432674408
# Macro F1 0.3333333432674408
#
#
# Epoch 1/29
# ----------
# train Loss: 0.8840 Main metric (macro_f1): 0.3344 Time: 9.31s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8839738585569479
# Micro Accuracy 0.6081081032752991
# Macro Accuracy 0.3343777060508728
# Macro Precision 0.3362974524497986
# Macro Recall 0.3343777060508728
# Macro F1 0.3343777060508728
#
# test Loss: 0.8517 Main metric (macro_f1): 0.3368 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8517080617022585
# Micro Accuracy 0.6156156063079834
# Macro Accuracy 0.3367697596549988
# Macro Precision 0.5381526350975037
# Macro Recall 0.3367697596549988
# Macro F1 0.3367697596549988
#
#
# Epoch 2/29
# ----------
# train Loss: 0.8517 Main metric (macro_f1): 0.3401 Time: 9.34s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8517030126697667
# Micro Accuracy 0.6118618845939636
# Macro Accuracy 0.34009063243865967
# Macro Precision 0.403999000787735
# Macro Recall 0.34009063243865967
# Macro F1 0.34009063243865967
#
# test Loss: 0.8329 Main metric (macro_f1): 0.3333 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8328833241720457
# Micro Accuracy 0.6126126050949097
# Macro Accuracy 0.3333333432674408
# Macro Precision 0.20420420169830322
# Macro Recall 0.3333333432674408
# Macro F1 0.3333333432674408
#
#
# Epoch 3/29
# ----------
# train Loss: 0.8204 Main metric (macro_f1): 0.3521 Time: 9.33s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8203548087372078
# Micro Accuracy 0.6186186075210571
# Macro Accuracy 0.35214924812316895
# Macro Precision 0.40041857957839966
# Macro Recall 0.35214924812316895
# Macro F1 0.35214924812316895
#
# test Loss: 0.8195 Main metric (macro_f1): 0.3402 Time: 0.99s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.819529984985386
# Micro Accuracy 0.6186186075210571
# Macro Accuracy 0.34020620584487915
# Macro Precision 0.538771390914917
# Macro Recall 0.34020620584487915
# Macro F1 0.34020620584487915
#
#
# Epoch 4/29
# ----------
# train Loss: 0.7881 Main metric (macro_f1): 0.3842 Time: 9.30s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7880660495958529
# Micro Accuracy 0.6456456184387207
# Macro Accuracy 0.3841961622238159
# Macro Precision 0.4640968441963196
# Macro Recall 0.3841961622238159
# Macro F1 0.3841961622238159
#
# test Loss: 0.8011 Main metric (macro_f1): 0.3402 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8010930465506362
# Micro Accuracy 0.6186186075210571
# Macro Accuracy 0.34020620584487915
# Macro Precision 0.42828285694122314
# Macro Recall 0.34020620584487915
# Macro F1 0.34020620584487915
#
#
# Epoch 5/29
# ----------
# train Loss: 0.7526 Main metric (macro_f1): 0.4072 Time: 9.32s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7525707823378188
# Micro Accuracy 0.662912905216217
# Macro Accuracy 0.4072379469871521
# Macro Precision 0.4548599421977997
# Macro Recall 0.4072379469871521
# Macro F1 0.4072379469871521
#
# test Loss: 0.7779 Main metric (macro_f1): 0.4278 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7778705598355772
# Micro Accuracy 0.6636636853218079
# Macro Accuracy 0.42780137062072754
# Macro Precision 0.42071330547332764
# Macro Recall 0.42780137062072754
# Macro F1 0.42780137062072754
#
#
# Epoch 6/29
# ----------
# train Loss: 0.7086 Main metric (macro_f1): 0.4610 Time: 9.33s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7085950274367232
# Micro Accuracy 0.7019519805908203
# Macro Accuracy 0.4610125422477722
# Macro Precision 0.4643811583518982
# Macro Recall 0.4610125422477722
# Macro F1 0.4610125422477722
#
# test Loss: 0.7469 Main metric (macro_f1): 0.4107 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7468514147105517
# Micro Accuracy 0.6786786913871765
# Macro Accuracy 0.41073715686798096
# Macro Precision 0.4956674873828888
# Macro Recall 0.41073715686798096
# Macro F1 0.41073715686798096
#
#
# Epoch 7/29
# ----------
# train Loss: 0.6495 Main metric (macro_f1): 0.5111 Time: 9.31s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.6494890660852999
# Micro Accuracy 0.7417417168617249
# Macro Accuracy 0.5111476182937622
# Macro Precision 0.8196979761123657
# Macro Recall 0.5111476182937622
# Macro F1 0.5111476182937622
#
# test Loss: 0.7184 Main metric (macro_f1): 0.4369 Time: 0.97s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7183678168076295
# Micro Accuracy 0.6906906962394714
# Macro Accuracy 0.43687039613723755
# Macro Precision 0.8087278604507446
# Macro Recall 0.43687039613723755
# Macro F1 0.43687039613723755
#
#
# Epoch 8/29
# ----------
# train Loss: 0.6045 Main metric (macro_f1): 0.5337 Time: 9.30s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.6045197154487576
# Micro Accuracy 0.7582582831382751
# Macro Accuracy 0.5337357521057129
# Macro Precision 0.824922502040863
# Macro Recall 0.5337357521057129
# Macro F1 0.5337357521057129
#
# test Loss: 0.6877 Main metric (macro_f1): 0.4748 Time: 0.97s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.6876578375741884
# Micro Accuracy 0.717717707157135
# Macro Accuracy 0.47477850317955017
# Macro Precision 0.8304864764213562
# Macro Recall 0.47477850317955017
# Macro F1 0.47477850317955017
#
#
# Epoch 9/29
# ----------
# train Loss: 0.5446 Main metric (macro_f1): 0.5801 Time: 9.30s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.544619324329021
# Micro Accuracy 0.792792797088623
# Macro Accuracy 0.5801142454147339
# Macro Precision 0.8442806005477905
# Macro Recall 0.5801142454147339
# Macro F1 0.5801142454147339
#
# test Loss: 0.6649 Main metric (macro_f1): 0.4919 Time: 0.97s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.6649245234939071
# Micro Accuracy 0.7297297120094299
# Macro Accuracy 0.4918995499610901
# Macro Precision 0.8457848429679871
# Macro Recall 0.4918995499610901
# Macro F1 0.4918995499610901
#
#
# Epoch 10/29
# ----------
# train Loss: 0.4852 Main metric (macro_f1): 0.6146 Time: 9.33s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4851908930787095
# Micro Accuracy 0.815315306186676
# Macro Accuracy 0.6146023273468018
# Macro Precision 0.8357808589935303
# Macro Recall 0.6146023273468018
# Macro F1 0.6146023273468018
#
# test Loss: 0.6120 Main metric (macro_f1): 0.5414 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.6119900895310594
# Micro Accuracy 0.7477477192878723
# Macro Accuracy 0.541357159614563
# Macro Precision 0.8138889074325562
# Macro Recall 0.541357159614563
# Macro F1 0.541357159614563
#
#
# Epoch 11/29
# ----------
# train Loss: 0.4387 Main metric (macro_f1): 0.6474 Time: 9.67s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4386885921518366
# Micro Accuracy 0.8385885953903198
# Macro Accuracy 0.6474131345748901
# Macro Precision 0.8548603057861328
# Macro Recall 0.6474131345748901
# Macro F1 0.6474131345748901
#
# test Loss: 0.5883 Main metric (macro_f1): 0.5426 Time: 1.02s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5883299307422237
# Micro Accuracy 0.7537537813186646
# Macro Accuracy 0.5425931215286255
# Macro Precision 0.6640000343322754
# Macro Recall 0.5425931215286255
# Macro F1 0.5425931215286255
#
#
# Epoch 12/29
# ----------
# train Loss: 0.3819 Main metric (macro_f1): 0.7133 Time: 10.19s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3818874863890914
# Micro Accuracy 0.8671171069145203
# Macro Accuracy 0.7132737636566162
# Macro Precision 0.8642739057540894
# Macro Recall 0.7132737636566162
# Macro F1 0.7132737636566162
#
# test Loss: 0.5618 Main metric (macro_f1): 0.5372 Time: 1.15s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5618461549461067
# Micro Accuracy 0.7567567825317383
# Macro Accuracy 0.5372469425201416
# Macro Precision 0.7468276023864746
# Macro Recall 0.5372469425201416
# Macro F1 0.5372469425201416
#
#
# Epoch 13/29
# ----------
# train Loss: 0.3554 Main metric (macro_f1): 0.7199 Time: 11.05s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3553519211373888
# Micro Accuracy 0.8753753900527954
# Macro Accuracy 0.7199313640594482
# Macro Precision 0.8659744262695312
# Macro Recall 0.7199313640594482
# Macro F1 0.7199313640594482
#
# test Loss: 0.5258 Main metric (macro_f1): 0.5719 Time: 1.19s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5258334232522203
# Micro Accuracy 0.7807807922363281
# Macro Accuracy 0.5719480514526367
# Macro Precision 0.7011111378669739
# Macro Recall 0.5719480514526367
# Macro F1 0.5719480514526367
#
#
# Epoch 14/29
# ----------
# train Loss: 0.3122 Main metric (macro_f1): 0.7477 Time: 11.17s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.31216861016757497
# Micro Accuracy 0.8903903961181641
# Macro Accuracy 0.7477353811264038
# Macro Precision 0.8827346563339233
# Macro Recall 0.7477353811264038
# Macro F1 0.7477353811264038
#
# test Loss: 0.5147 Main metric (macro_f1): 0.5890 Time: 1.06s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5147050561847629
# Micro Accuracy 0.7897897958755493
# Macro Accuracy 0.589008092880249
# Macro Precision 0.7236127853393555
# Macro Recall 0.589008092880249
# Macro F1 0.589008092880249
#
#
# Epoch 15/29
# ----------
# train Loss: 0.2830 Main metric (macro_f1): 0.7741 Time: 11.12s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2830371617286413
# Micro Accuracy 0.9054054021835327
# Macro Accuracy 0.7741413712501526
# Macro Precision 0.9078726172447205
# Macro Recall 0.7741413712501526
# Macro F1 0.7741413712501526
#
# test Loss: 0.4991 Main metric (macro_f1): 0.5907 Time: 1.21s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4990513718521989
# Micro Accuracy 0.7867867946624756
# Macro Accuracy 0.5907495021820068
# Macro Precision 0.653174638748169
# Macro Recall 0.5907495021820068
# Macro F1 0.5907495021820068
#
#
# Epoch 16/29
# ----------
# train Loss: 0.2518 Main metric (macro_f1): 0.8202 Time: 11.87s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2517646195831241
# Micro Accuracy 0.9219219088554382
# Macro Accuracy 0.8201524019241333
# Macro Precision 0.9211187958717346
# Macro Recall 0.8201524019241333
# Macro F1 0.8201524019241333
#
# test Loss: 0.4956 Main metric (macro_f1): 0.5788 Time: 1.20s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4955774468702597
# Micro Accuracy 0.7747747898101807
# Macro Accuracy 0.5788061618804932
# Macro Precision 0.6297727227210999
# Macro Recall 0.5788061618804932
# Macro F1 0.5788061618804932
#
#
# Epoch 17/29
# ----------
# train Loss: 0.2335 Main metric (macro_f1): 0.8551 Time: 11.13s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.23348853636432337
# Micro Accuracy 0.9376876950263977
# Macro Accuracy 0.8550975322723389
# Macro Precision 0.9319617748260498
# Macro Recall 0.8550975322723389
# Macro F1 0.8550975322723389
#
# test Loss: 0.4857 Main metric (macro_f1): 0.5960 Time: 1.11s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.48567285337247645
# Micro Accuracy 0.7897897958755493
# Macro Accuracy 0.5959883332252502
# Macro Precision 0.662972092628479
# Macro Recall 0.5959883332252502
# Macro F1 0.5959883332252502
#
#
# Epoch 18/29
# ----------
# train Loss: 0.2084 Main metric (macro_f1): 0.8768 Time: 13.21s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2084359877907836
# Micro Accuracy 0.9481981992721558
# Macro Accuracy 0.876777172088623
# Macro Precision 0.9383124113082886
# Macro Recall 0.876777172088623
# Macro F1 0.876777172088623
#
# test Loss: 0.4771 Main metric (macro_f1): 0.6097 Time: 1.26s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4771020190493839
# Micro Accuracy 0.8018018007278442
# Macro Accuracy 0.609734058380127
# Macro Precision 0.6651071906089783
# Macro Recall 0.609734058380127
# Macro F1 0.609734058380127
#
#
# Epoch 19/29
# ----------
# train Loss: 0.1974 Main metric (macro_f1): 0.8674 Time: 11.16s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.19741572148807057
# Micro Accuracy 0.9436936974525452
# Macro Accuracy 0.8674353361129761
# Macro Precision 0.9373614192008972
# Macro Recall 0.8674353361129761
# Macro F1 0.8674353361129761
#
# test Loss: 0.4658 Main metric (macro_f1): 0.6379 Time: 1.13s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4657986940922322
# Micro Accuracy 0.8018018007278442
# Macro Accuracy 0.6378844976425171
# Macro Precision 0.6931419968605042
# Macro Recall 0.6378844976425171
# Macro F1 0.6378844976425171
#
#
# Epoch 20/29
# ----------
# train Loss: 0.1654 Main metric (macro_f1): 0.9226 Time: 12.78s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.16541450088088577
# Micro Accuracy 0.9692192077636719
# Macro Accuracy 0.9226042032241821
# Macro Precision 0.9618078470230103
# Macro Recall 0.9226042032241821
# Macro F1 0.9226042032241821
#
# test Loss: 0.4762 Main metric (macro_f1): 0.6290 Time: 1.26s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.47619489336514975
# Micro Accuracy 0.7957957983016968
# Macro Accuracy 0.6289797425270081
# Macro Precision 0.6746621131896973
# Macro Recall 0.6289797425270081
# Macro F1 0.6289797425270081
#
#
# Epoch 21/29
# ----------
# train Loss: 0.1506 Main metric (macro_f1): 0.9375 Time: 13.55s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.1505861809930286
# Micro Accuracy 0.9729729890823364
# Macro Accuracy 0.9375312328338623
# Macro Precision 0.9624669551849365
# Macro Recall 0.9375312328338623
# Macro F1 0.9375312328338623
#
# test Loss: 0.4668 Main metric (macro_f1): 0.6533 Time: 1.23s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4668180127670099
# Micro Accuracy 0.8078078031539917
# Macro Accuracy 0.6533105373382568
# Macro Precision 0.696952760219574
# Macro Recall 0.6533105373382568
# Macro F1 0.6533105373382568
#
#
# Epoch 22/29
# ----------
# train Loss: 0.1320 Main metric (macro_f1): 0.9611 Time: 11.73s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.1320429009360236
# Micro Accuracy 0.9827327132225037
# Macro Accuracy 0.9610986709594727
# Macro Precision 0.9790520668029785
# Macro Recall 0.9610986709594727
# Macro F1 0.9610986709594727
#
# test Loss: 0.4642 Main metric (macro_f1): 0.6618 Time: 1.20s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4642075412087254
# Micro Accuracy 0.8168168067932129
# Macro Accuracy 0.6618173718452454
# Macro Precision 0.7170815467834473
# Macro Recall 0.6618173718452454
# Macro F1 0.6618173718452454
#
#
# Epoch 23/29
# ----------
# train Loss: 0.1214 Main metric (macro_f1): 0.9535 Time: 12.18s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.12138503344656827
# Micro Accuracy 0.9797297120094299
# Macro Accuracy 0.9535400867462158
# Macro Precision 0.9728696942329407
# Macro Recall 0.9535400867462158
# Macro F1 0.9535400867462158
#
# test Loss: 0.4658 Main metric (macro_f1): 0.6620 Time: 1.22s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.46575572129126425
# Micro Accuracy 0.8138138055801392
# Macro Accuracy 0.6619858145713806
# Macro Precision 0.6825611591339111
# Macro Recall 0.6619858145713806
# Macro F1 0.6619858145713806
#
#
# Epoch 24/29
# ----------
# train Loss: 0.1039 Main metric (macro_f1): 0.9739 Time: 13.67s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.10393116961012373
# Micro Accuracy 0.9894894957542419
# Macro Accuracy 0.9738901853561401
# Macro Precision 0.986525297164917
# Macro Recall 0.9738901853561401
# Macro F1 0.9738901853561401
#
# test Loss: 0.4705 Main metric (macro_f1): 0.6533 Time: 1.14s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4704688674694783
# Micro Accuracy 0.8078078031539917
# Macro Accuracy 0.6533105373382568
# Macro Precision 0.696952760219574
# Macro Recall 0.6533105373382568
# Macro F1 0.6533105373382568
#
#
# Epoch 25/29
# ----------
# train Loss: 0.0928 Main metric (macro_f1): 0.9825 Time: 13.15s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.09275366612024852
# Micro Accuracy 0.9924924969673157
# Macro Accuracy 0.9824931621551514
# Macro Precision 0.9896711111068726
# Macro Recall 0.9824931621551514
# Macro F1 0.9824931621551514
#
# test Loss: 0.4620 Main metric (macro_f1): 0.6727 Time: 1.23s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4619816489763804
# Micro Accuracy 0.8078078031539917
# Macro Accuracy 0.6726783514022827
# Macro Precision 0.6849448680877686
# Macro Recall 0.6726783514022827
# Macro F1 0.6726783514022827
#
#
# Epoch 26/29
# ----------
# train Loss: 0.0841 Main metric (macro_f1): 0.9895 Time: 12.73s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.0841391711599297
# Micro Accuracy 0.9954954981803894
# Macro Accuracy 0.9894875288009644
# Macro Precision 0.9949843883514404
# Macro Recall 0.9894875288009644
# Macro F1 0.9894875288009644
#
# test Loss: 0.4714 Main metric (macro_f1): 0.6446 Time: 1.21s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4714136768031765
# Micro Accuracy 0.8018018007278442
# Macro Accuracy 0.6446352005004883
# Macro Precision 0.6830700635910034
# Macro Recall 0.6446352005004883
# Macro F1 0.6446352005004883
#
#
# Epoch 27/29
# ----------
# train Loss: 0.0782 Main metric (macro_f1): 0.9851 Time: 11.74s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.0782244480452738
# Micro Accuracy 0.9932432174682617
# Macro Accuracy 0.9850776195526123
# Macro Precision 0.9920441508293152
# Macro Recall 0.9850776195526123
# Macro F1 0.9850776195526123
#
# test Loss: 0.4730 Main metric (macro_f1): 0.6848 Time: 1.26s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4730298905759244
# Micro Accuracy 0.8168168067932129
# Macro Accuracy 0.6847900152206421
# Macro Precision 0.6953654885292053
# Macro Recall 0.6847900152206421
# Macro F1 0.6847900152206421
#
#
# Epoch 28/29
# ----------

# %%
BEST_MODEL_PATH = './trained_models/{}/{}/best_model.pth'.format(MODEL_NAME, EXPERIMENT_NAME)
os.makedirs(os.path.dirname(BEST_MODEL_PATH), exist_ok=True)
torch.save(model.state_dict(), BEST_MODEL_PATH)

# %% [markdown]
# ## Evaluación final

# %%
from dataset_modules.common import pil_loader
model.load_state_dict(torch.load(BEST_MODEL_PATH))
model.eval()

metrics = metrics_helper.init_metrics(device, NUM_CLASSES)
tensorboard_transforms = transforms.Compose([
    transforms.ToTensor()
])

total_loss = 0.0

for i, (images, labels, imgs_path) in enumerate(test_loader):
    images = images.to(device)
    labels = labels.to(device)
    
    with torch.no_grad():
        outputs = model(images)
        metrics(outputs, labels)
        
        predictions = torch.argmax(outputs, dim=1)
        loss = criterion(outputs, labels)
        
        total_loss += loss.item() * images.size(0)
        
        for sampleno in range(images.shape[0]):
            if(labels[sampleno] != predictions[sampleno]):
                name = 'Misclasified_Predicted-{}_Classified-{}/{}'.format(classes[predictions[sampleno]], classes[labels[sampleno]], imgs_path[sampleno])
                
                writer.add_image(name, tensorboard_transforms(pil_loader('/scratch/franco.cuevas/imgs/' + imgs_path[sampleno])))
                writer.flush()
        
total_loss /= dataset_sizes["test"]

metrics_result = metrics.compute()

# %%
macro_metrics = metrics_helper.generate_macro_metrics(metrics_result, total_loss)
per_class_metrics = metrics_helper.generate_per_class_metrics(metrics_result, classes)

macro_metrics.to_csv('./trained_models/{}/{}/best_model_macro_metrics.csv'.format(MODEL_NAME, EXPERIMENT_NAME), index=False)
per_class_metrics.to_csv('./trained_models/{}/{}/best_model_per_class_metrics.csv'.format(MODEL_NAME, EXPERIMENT_NAME), index=False)

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

df_cm = pd.DataFrame(metrics_result['confusion_matrix'], index = classes,
                  columns = classes)

df_cm = df_cm.applymap(lambda x: x.item())

plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap="Blues")
df_cm.to_csv('./trained_models/{}/{}/confusion_matrix.csv'.format(MODEL_NAME, EXPERIMENT_NAME))
