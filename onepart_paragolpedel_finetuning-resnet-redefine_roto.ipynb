# %% [markdown]
# ## Introducción
#
# Entrenamiento de modelo preentrenado para resolver el problema de predecir el ángulo del auto en base a la imagen.
#
# Fuertemente basado en:
# - https://towardsdatascience.com/a-practical-example-in-transfer-learning-with-pytorch-846bb835f2db
# - https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

# %% [markdown]
# ## Imports

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.datasets as datasets
import torchvision.models as models
import torchvision.transforms as transforms
from torchmetrics import MetricCollection, Accuracy, Precision, Recall, F1, ConfusionMatrix
import pandas as pd
import sklearn
from torch.utils.tensorboard import SummaryWriter

from datetime import datetime
import os

import importlib
import training_helper
import dataset_modules.one_part_dataset as opd
import metrics_helper

importlib.reload(training_helper)
importlib.reload(metrics_helper)
#importlib.reload(dataset_modules)
# Out:
# <module 'metrics_helper' from '/clusteruy/home/franco.cuevas/tesis-jupyters-2/metrics_helper.py'>

# %% [markdown]
# ## Variables

# %%
MODEL_NAME = "one_part_model"
EXPERIMENT_NAME = "resnet50_paragolpe_fine_tuning-redefine_roto"
FEATURE_EXTRACTION = False

device_string = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(device_string)

if device_string == "cuda":
    print("Usando GPU!")

os.makedirs("./trained_models/{}/{}/".format(MODEL_NAME, EXPERIMENT_NAME), exist_ok=True)
# Out:
# Usando GPU!

# %% [markdown]
# ## Dataset
#
# Se crea un dataset de tipo `ImageFolder` que se toma de la carpeta `dataset`, donde cada subcarpeta es una de las categorías a entrenar.
#
# Automáticamente mapea categorías a números `dataset.class_to_idx`.
#
# Finalmente se hace el split en train y test en 80/20.

# %%
print("start to load dataset")
dataset = opd.OnePartDataset(
    "Paragolpe Delantero",
    transform=transforms.Compose([
        transforms.ColorJitter(0.1, 0.1, 0.1, 0.1),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    preload=True,
    #ignore_repair=True
    visibility_file="./dataset_modules/analisis_manual_paragolpe.csv"
)
print("finish to load dataset")

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size], generator=torch.Generator().manual_seed(42))

classes = dataset.classes

dataset_sizes = {
    'train': len(train_dataset),
    'test': len(test_dataset)
}

print("#TRAIN {} #TEST {}".format(dataset_sizes["train"], dataset_sizes["test"]))
# Out:
# start to load dataset
# ----- CLASS DISTRIBUTION -----
# Class: no_paragolpe_delantero, #916, 55.02%
# Class: paragolpe_delantero_sano, #475, 28.53%
# Class: paragolpe_delantero_roto, #274, 16.46%
# finish to load dataset
# #TRAIN 1332 #TEST 333

# %%
Class: no_paragolpe_delantero, #916, 55.02%
Class: paragolpe_delantero_roto, #407, 24.44%
Class: paragolpe_delantero_sano, #342, 20.54%


Class: no_paragolpe_delantero, #916, 55.02%
Class: paragolpe_delantero_sano, #475, 28.53%
Class: paragolpe_delantero_roto, #274, 16.46%
finish to load dataset
#TRAIN 1332 #TEST 333

# %% [markdown]
# ## Loaders
# Luego, se crean loaders para cada uno de los conjuntos. Los loaders permiten procesar los datos de a batches.

# %%
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True,
    num_workers=0
)

test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=16,
    shuffle=True,
    num_workers=0
)

dataloaders = {
    'train': train_loader,
    'test': test_loader
}

# %% [markdown]
# ## Entrenamiento
#
# En este step se carga el modelo pre-entrenado. Para este ejemplo se utiliza el modelo alexnet por su simplicidad.

# %% [markdown]
# #### ¿Finetuning o Feature extraction?
#
# - **Finetuning:** Consiste en incializar la red con los pesos pre-entrenados, y re-entrenar toda la red (ajustar los parámetros de todas las capas) con el dataset custom.
# - **Feature extraction:** La diferencia con lo anterior es que se congelan las capas convolucionales, de modo que el entrenamiento no las cambie con nuestros datos.
#
# En ambos casos pisamos la capa de **clasificador** por una capa nueva con 8 categorías, porque el modelo pre-entrenado tiene 1000 labels.

# %%
model = models.resnet50(pretrained=True)
NUM_CLASSES = len(classes)

if FEATURE_EXTRACTION:
    for param in model.parameters():
        param.requires_grad = False

model.fc = torch.nn.Linear(2048, NUM_CLASSES)
model = model.to(device)

# Tensorboard metrics writer
writer = SummaryWriter(log_dir='./trained_models/{}/tensorboard/{}'.format(MODEL_NAME, EXPERIMENT_NAME + '-' + datetime.now().strftime("%Y%m%d-%H%M%S")))

# Función de error
criterion = F.cross_entropy

# Optimizador
parameters_to_update = model.parameters()

if FEATURE_EXTRACTION:
    parameters_to_update = model.fc.parameters()

optimizer = optim.SGD(parameters_to_update, lr=0.001)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=3, bias=True)
# )

# %%
model = training_helper.train_model(
    model, 
    criterion, 
    optimizer, 
    dataloaders, 
    dataset_sizes, 
    device, 
    writer, 
    NUM_CLASSES,
    'trained_models/{}/{}'.format(MODEL_NAME, EXPERIMENT_NAME),
    main_metric='macro_f1', 
    num_epochs=30
)
# Out:
# Epoch 0/29
# ----------
# train Loss: 0.9633 Main metric (macro_f1): 0.3469 Time: 10.80s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.9632625996887505
# Micro Accuracy 0.5420420169830322
# Macro Accuracy 0.3468884825706482
# Macro Precision 0.35798922181129456
# Macro Recall 0.3468884825706482
# Macro F1 0.3468884825706482
#
# test Loss: 0.8343 Main metric (macro_f1): 0.3933 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8342523841528563
# Micro Accuracy 0.6366366147994995
# Macro Accuracy 0.3932584524154663
# Macro Precision 0.4179403781890869
# Macro Recall 0.3932584524154663
# Macro F1 0.3932584524154663
#
#
# Epoch 1/29
# ----------
# train Loss: 0.8259 Main metric (macro_f1): 0.4440 Time: 9.31s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8259157128520198
# Micro Accuracy 0.6351351141929626
# Macro Accuracy 0.44395479559898376
# Macro Precision 0.5941931009292603
# Macro Recall 0.44395479559898376
# Macro F1 0.44395479559898376
#
# test Loss: 0.7071 Main metric (macro_f1): 0.5019 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7071226987394843
# Micro Accuracy 0.7237237095832825
# Macro Accuracy 0.5018726587295532
# Macro Precision 0.4648660719394684
# Macro Recall 0.5018726587295532
# Macro F1 0.5018726587295532
#
#
# Epoch 2/29
# ----------
# train Loss: 0.7062 Main metric (macro_f1): 0.5443 Time: 9.31s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7062033964348985
# Micro Accuracy 0.7214714884757996
# Macro Accuracy 0.5442759394645691
# Macro Precision 0.7992461323738098
# Macro Recall 0.5442759394645691
# Macro F1 0.5442759394645691
#
# test Loss: 0.5930 Main metric (macro_f1): 0.6050 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5929624078510044
# Micro Accuracy 0.804804801940918
# Macro Accuracy 0.6050409078598022
# Macro Precision 0.5120120048522949
# Macro Recall 0.6050409078598022
# Macro F1 0.6050409078598022
#
#
# Epoch 3/29
# ----------
# train Loss: 0.5986 Main metric (macro_f1): 0.6031 Time: 9.31s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5985871370848235
# Micro Accuracy 0.7710210084915161
# Macro Accuracy 0.6030838489532471
# Macro Precision 0.7466098070144653
# Macro Recall 0.6030838489532471
# Macro F1 0.6030838489532471
#
# test Loss: 0.5060 Main metric (macro_f1): 0.6071 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5060152048105234
# Micro Accuracy 0.804804801940918
# Macro Accuracy 0.6070855259895325
# Macro Precision 0.5130103826522827
# Macro Recall 0.6070855259895325
# Macro F1 0.6070855259895325
#
#
# Epoch 4/29
# ----------
# train Loss: 0.5215 Main metric (macro_f1): 0.6494 Time: 9.37s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5215351635271365
# Micro Accuracy 0.8003003001213074
# Macro Accuracy 0.6493696570396423
# Macro Precision 0.8202294111251831
# Macro Recall 0.6493696570396423
# Macro F1 0.6493696570396423
#
# test Loss: 0.4545 Main metric (macro_f1): 0.6299 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.45448367293174563
# Micro Accuracy 0.8198198080062866
# Macro Accuracy 0.6299014091491699
# Macro Precision 0.5269206762313843
# Macro Recall 0.6299014091491699
# Macro F1 0.6299014091491699
#
#
# Epoch 5/29
# ----------
# train Loss: 0.4570 Main metric (macro_f1): 0.6693 Time: 9.33s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.457037967246574
# Micro Accuracy 0.81456458568573
# Macro Accuracy 0.6692556142807007
# Macro Precision 0.7799228429794312
# Macro Recall 0.6692556142807007
# Macro F1 0.6692556142807007
#
# test Loss: 0.4090 Main metric (macro_f1): 0.6528 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.40904156420681925
# Micro Accuracy 0.8288288116455078
# Macro Accuracy 0.6527794003486633
# Macro Precision 0.7322956323623657
# Macro Recall 0.6527794003486633
# Macro F1 0.6527794003486633
#
#
# Epoch 6/29
# ----------
# train Loss: 0.4325 Main metric (macro_f1): 0.7077 Time: 9.31s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4324733634610792
# Micro Accuracy 0.8325825929641724
# Macro Accuracy 0.7076897621154785
# Macro Precision 0.8287638425827026
# Macro Recall 0.7076897621154785
# Macro F1 0.7076897621154785
#
# test Loss: 0.3886 Main metric (macro_f1): 0.6533 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3886206482981776
# Micro Accuracy 0.8318318128585815
# Macro Accuracy 0.6533255577087402
# Macro Precision 0.7019842863082886
# Macro Recall 0.6533255577087402
# Macro F1 0.6533255577087402
#
#
# Epoch 7/29
# ----------
# train Loss: 0.3928 Main metric (macro_f1): 0.7299 Time: 9.31s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3928288840674781
# Micro Accuracy 0.847597599029541
# Macro Accuracy 0.7298519015312195
# Macro Precision 0.8438437581062317
# Macro Recall 0.7298519015312195
# Macro F1 0.7298519015312195
#
# test Loss: 0.3673 Main metric (macro_f1): 0.6565 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3672685111249173
# Micro Accuracy 0.8318318128585815
# Macro Accuracy 0.6565247178077698
# Macro Precision 0.734597384929657
# Macro Recall 0.6565247178077698
# Macro F1 0.6565247178077698
#
#
# Epoch 8/29
# ----------
# train Loss: 0.3557 Main metric (macro_f1): 0.7551 Time: 9.31s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.35565784018676916
# Micro Accuracy 0.8633633852005005
# Macro Accuracy 0.7551331520080566
# Macro Precision 0.8636350631713867
# Macro Recall 0.7551331520080566
# Macro F1 0.7551331520080566
#
# test Loss: 0.3547 Main metric (macro_f1): 0.6987 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.35473283677845746
# Micro Accuracy 0.8528528809547424
# Macro Accuracy 0.6987375617027283
# Macro Precision 0.7921218872070312
# Macro Recall 0.6987375617027283
# Macro F1 0.6987375617027283
#
#
# Epoch 9/29
# ----------
# train Loss: 0.3375 Main metric (macro_f1): 0.7834 Time: 9.37s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.33749543904542206
# Micro Accuracy 0.8783783912658691
# Macro Accuracy 0.7834089994430542
# Macro Precision 0.8706207871437073
# Macro Recall 0.7834089994430542
# Macro F1 0.7834089994430542
#
# test Loss: 0.3435 Main metric (macro_f1): 0.7405 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3434926273228528
# Micro Accuracy 0.8648648858070374
# Macro Accuracy 0.7404663562774658
# Macro Precision 0.7763398885726929
# Macro Recall 0.7404663562774658
# Macro F1 0.7404663562774658
#
#
# Epoch 10/29
# ----------
# train Loss: 0.3207 Main metric (macro_f1): 0.8016 Time: 9.31s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3207157663217894
# Micro Accuracy 0.8858858942985535
# Macro Accuracy 0.8016366362571716
# Macro Precision 0.8741040825843811
# Macro Recall 0.8016366362571716
# Macro F1 0.8016366362571716
#
# test Loss: 0.3294 Main metric (macro_f1): 0.7277 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.329355117079016
# Micro Accuracy 0.8648648858070374
# Macro Accuracy 0.7276698350906372
# Macro Precision 0.8129773139953613
# Macro Recall 0.7276698350906372
# Macro F1 0.7276698350906372
#
#
# Epoch 11/29
# ----------
# train Loss: 0.2949 Main metric (macro_f1): 0.8211 Time: 9.38s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.29489089723105905
# Micro Accuracy 0.9001501798629761
# Macro Accuracy 0.8211220502853394
# Macro Precision 0.8942797780036926
# Macro Recall 0.8211220502853394
# Macro F1 0.8211220502853394
#
# test Loss: 0.3227 Main metric (macro_f1): 0.7352 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.32274285621113247
# Micro Accuracy 0.8708708882331848
# Macro Accuracy 0.7351604700088501
# Macro Precision 0.8178703784942627
# Macro Recall 0.7351604700088501
# Macro F1 0.7351604700088501
#
#
# Epoch 12/29
# ----------
# train Loss: 0.2727 Main metric (macro_f1): 0.8573 Time: 9.37s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.27270028411268116
# Micro Accuracy 0.9174174070358276
# Macro Accuracy 0.8572590947151184
# Macro Precision 0.9084817171096802
# Macro Recall 0.8572590947151184
# Macro F1 0.8572590947151184
#
# test Loss: 0.3140 Main metric (macro_f1): 0.7378 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3140448245916281
# Micro Accuracy 0.8678678870201111
# Macro Accuracy 0.7378134727478027
# Macro Precision 0.8015912771224976
# Macro Recall 0.7378134727478027
# Macro F1 0.7378134727478027
#
#
# Epoch 13/29
# ----------
# train Loss: 0.2551 Main metric (macro_f1): 0.8693 Time: 9.36s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2550841326470132
# Micro Accuracy 0.9241741895675659
# Macro Accuracy 0.8693106770515442
# Macro Precision 0.9141424894332886
# Macro Recall 0.8693106770515442
# Macro F1 0.8693106770515442
#
# test Loss: 0.3056 Main metric (macro_f1): 0.7697 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3056262668457117
# Micro Accuracy 0.8738738894462585
# Macro Accuracy 0.7697426080703735
# Macro Precision 0.7929434776306152
# Macro Recall 0.7697426080703735
# Macro F1 0.7697426080703735
#
#
# Epoch 14/29
# ----------
# train Loss: 0.2295 Main metric (macro_f1): 0.8860 Time: 9.31s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.22952224895939813
# Micro Accuracy 0.9361861944198608
# Macro Accuracy 0.8860155344009399
# Macro Precision 0.9331252574920654
# Macro Recall 0.8860155344009399
# Macro F1 0.8860155344009399
#
# test Loss: 0.3096 Main metric (macro_f1): 0.7793 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.30955524814200475
# Micro Accuracy 0.879879891872406
# Macro Accuracy 0.7792778611183167
# Macro Precision 0.8073186874389648
# Macro Recall 0.7792778611183167
# Macro F1 0.7792778611183167
#
#
# Epoch 15/29
# ----------
# train Loss: 0.2059 Main metric (macro_f1): 0.9094 Time: 9.32s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.205925034554871
# Micro Accuracy 0.9474474191665649
# Macro Accuracy 0.9093621969223022
# Macro Precision 0.938044011592865
# Macro Recall 0.9093621969223022
# Macro F1 0.9093621969223022
#
# test Loss: 0.2988 Main metric (macro_f1): 0.7819 Time: 0.99s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.29879810555919156
# Micro Accuracy 0.8768768906593323
# Macro Accuracy 0.7819308042526245
# Macro Precision 0.7975786924362183
# Macro Recall 0.7819308042526245
# Macro F1 0.7819308042526245
#
#
# Epoch 16/29
# ----------
# train Loss: 0.1868 Main metric (macro_f1): 0.9149 Time: 9.33s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.18683334048445877
# Micro Accuracy 0.9512012004852295
# Macro Accuracy 0.9149026870727539
# Macro Precision 0.9435442686080933
# Macro Recall 0.9149026870727539
# Macro F1 0.9149026870727539
#
# test Loss: 0.2921 Main metric (macro_f1): 0.7836 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2921283048641932
# Micro Accuracy 0.879879891872406
# Macro Accuracy 0.783631443977356
# Macro Precision 0.8091782331466675
# Macro Recall 0.783631443977356
# Macro F1 0.783631443977356
#
#
# Epoch 17/29
# ----------
# train Loss: 0.1746 Main metric (macro_f1): 0.9347 Time: 9.32s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.1745614545481341
# Micro Accuracy 0.9617117047309875
# Macro Accuracy 0.9347295761108398
# Macro Precision 0.9587390422821045
# Macro Recall 0.9347295761108398
# Macro F1 0.9347295761108398
#
# test Loss: 0.2885 Main metric (macro_f1): 0.7704 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2884793158050056
# Micro Accuracy 0.8708708882331848
# Macro Accuracy 0.7703508734703064
# Macro Precision 0.7853050231933594
# Macro Recall 0.7703508734703064
# Macro F1 0.7703508734703064
#
#
# Epoch 18/29
# ----------
# train Loss: 0.1434 Main metric (macro_f1): 0.9507 Time: 9.32s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.14336442007674827
# Micro Accuracy 0.9722222089767456
# Macro Accuracy 0.9507192969322205
# Macro Precision 0.9658308029174805
# Macro Recall 0.9507192969322205
# Macro F1 0.9507192969322205
#
# test Loss: 0.2839 Main metric (macro_f1): 0.7880 Time: 0.99s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2839388335431302
# Micro Accuracy 0.879879891872406
# Macro Accuracy 0.78798508644104
# Macro Precision 0.805871307849884
# Macro Recall 0.78798508644104
# Macro F1 0.78798508644104
#
#
# Epoch 19/29
# ----------
# train Loss: 0.1375 Main metric (macro_f1): 0.9564 Time: 9.30s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.1374886578267759
# Micro Accuracy 0.9759759902954102
# Macro Accuracy 0.9564496278762817
# Macro Precision 0.9746310710906982
# Macro Recall 0.9564496278762817
# Macro F1 0.9564496278762817
#
# test Loss: 0.2820 Main metric (macro_f1): 0.8013 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.28203949491093466
# Micro Accuracy 0.8828828930854797
# Macro Accuracy 0.8013277649879456
# Macro Precision 0.8151766061782837
# Macro Recall 0.8013277649879456
# Macro F1 0.8013277649879456
#
#
# Epoch 20/29
# ----------
# train Loss: 0.1221 Main metric (macro_f1): 0.9679 Time: 9.35s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.12206218255174768
# Micro Accuracy 0.9827327132225037
# Macro Accuracy 0.9679108262062073
# Macro Precision 0.9809237718582153
# Macro Recall 0.9679108262062073
# Macro F1 0.9679108262062073
#
# test Loss: 0.2829 Main metric (macro_f1): 0.8088 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2829116421329367
# Micro Accuracy 0.8888888955116272
# Macro Accuracy 0.8088183999061584
# Macro Precision 0.8150448799133301
# Macro Recall 0.8088183999061584
# Macro F1 0.8088183999061584
#
#
# Epoch 21/29
# ----------
# train Loss: 0.1064 Main metric (macro_f1): 0.9803 Time: 9.32s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.10636067302064137
# Micro Accuracy 0.9879879951477051
# Macro Accuracy 0.9802592396736145
# Macro Precision 0.9888008236885071
# Macro Recall 0.9802592396736145
# Macro F1 0.9802592396736145
#
# test Loss: 0.2793 Main metric (macro_f1): 0.8051 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2792833024585569
# Micro Accuracy 0.8858858942985535
# Macro Accuracy 0.805073082447052
# Macro Precision 0.8161545395851135
# Macro Recall 0.805073082447052
# Macro F1 0.805073082447052
#
#
# Epoch 22/29
# ----------
# train Loss: 0.1018 Main metric (macro_f1): 0.9788 Time: 9.37s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.1017687520398213
# Micro Accuracy 0.9879879951477051
# Macro Accuracy 0.9788466691970825
# Macro Precision 0.987321138381958
# Macro Recall 0.9788466691970825
# Macro F1 0.9788466691970825
#
# test Loss: 0.2879 Main metric (macro_f1): 0.8300 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2878648398874758
# Micro Accuracy 0.8948948979377747
# Macro Accuracy 0.8299956917762756
# Macro Precision 0.8263150453567505
# Macro Recall 0.8299956917762756
# Macro F1 0.8299956917762756
#
#
# Epoch 23/29
# ----------
# train Loss: 0.0858 Main metric (macro_f1): 0.9847 Time: 9.36s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.0858245872565218
# Micro Accuracy 0.9909909963607788
# Macro Accuracy 0.9847463965415955
# Macro Precision 0.9906380772590637
# Macro Recall 0.9847463965415955
# Macro F1 0.9847463965415955
#
# test Loss: 0.2958 Main metric (macro_f1): 0.8199 Time: 0.97s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2958200730540015
# Micro Accuracy 0.8918918967247009
# Macro Accuracy 0.8198521137237549
# Macro Precision 0.8217386603355408
# Macro Recall 0.8198521137237549
# Macro F1 0.8198521137237549
#
#
# Epoch 24/29
# ----------
# train Loss: 0.0797 Main metric (macro_f1): 0.9900 Time: 9.32s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.07967029545489732
# Micro Accuracy 0.9932432174682617
# Macro Accuracy 0.9899723529815674
# Macro Precision 0.9936093091964722
# Macro Recall 0.9899723529815674
# Macro F1 0.9899723529815674
#
# test Loss: 0.2829 Main metric (macro_f1): 0.8334 Time: 0.99s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.28285515321804594
# Micro Accuracy 0.9009009003639221
# Macro Accuracy 0.8333970904350281
# Macro Precision 0.8354515433311462
# Macro Recall 0.8333970904350281
# Macro F1 0.8333970904350281
#
#
# Epoch 25/29
# ----------
# train Loss: 0.0674 Main metric (macro_f1): 0.9868 Time: 9.31s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.06735521816724055
# Micro Accuracy 0.9909909963607788
# Macro Accuracy 0.9867703318595886
# Macro Precision 0.9899956583976746
# Macro Recall 0.9867703318595886
# Macro F1 0.9867703318595886
#
# test Loss: 0.2812 Main metric (macro_f1): 0.8334 Time: 1.06s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2812143299538452
# Micro Accuracy 0.9009009003639221
# Macro Accuracy 0.8333970904350281
# Macro Precision 0.8354515433311462
# Macro Recall 0.8333970904350281
# Macro F1 0.8333970904350281
#
#
# Epoch 26/29
# ----------
# train Loss: 0.0590 Main metric (macro_f1): 0.9923 Time: 9.32s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.05904753101212126
# Micro Accuracy 0.9947447180747986
# Macro Accuracy 0.9923108816146851
# Macro Precision 0.9948005676269531
# Macro Recall 0.9923108816146851
# Macro F1 0.9923108816146851
#
# test Loss: 0.2869 Main metric (macro_f1): 0.8222 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2868653986905072
# Micro Accuracy 0.8918918967247009
# Macro Accuracy 0.8221611380577087
# Macro Precision 0.8300073146820068
# Macro Recall 0.8221611380577087
# Macro F1 0.8221611380577087
#
#
# Epoch 27/29
# ----------
# train Loss: 0.0588 Main metric (macro_f1): 0.9919 Time: 9.32s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.05883516637502132
# Micro Accuracy 0.9947447180747986
# Macro Accuracy 0.9919102191925049
# Macro Precision 0.9941442012786865
# Macro Recall 0.9919102191925049
# Macro F1 0.9919102191925049
#
# test Loss: 0.2830 Main metric (macro_f1): 0.8334 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.28299768094543937
# Micro Accuracy 0.9009009003639221
# Macro Accuracy 0.8333970904350281
# Macro Precision 0.8354515433311462
# Macro Recall 0.8333970904350281
# Macro F1 0.8333970904350281
#
#
# Epoch 28/29
# ----------
# train Loss: 0.0539 Main metric (macro_f1): 0.9930 Time: 9.32s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.05391170670678308
# Micro Accuracy 0.9954954981803894
# Macro Accuracy 0.9929845929145813
# Macro Precision 0.996833086013794
# Macro Recall 0.9929845929145813
# Macro F1 0.9929845929145813
#
# test Loss: 0.2929 Main metric (macro_f1): 0.7880 Time: 0.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.29294406309410614
# Micro Accuracy 0.879879891872406
# Macro Accuracy 0.78798508644104
# Macro Precision 0.8196988701820374
# Macro Recall 0.78798508644104
# Macro F1 0.78798508644104
#
#
# Epoch 29/29
# ----------
# train Loss: 0.0510 Main metric (macro_f1): 0.9938 Time: 9.33s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.050975425912811234
# Micro Accuracy 0.9954954981803894
# Macro Accuracy 0.9937857389450073
# Macro Precision 0.9939960837364197
# Macro Recall 0.9937857389450073
# Macro F1 0.9937857389450073
#
# test Loss: 0.2878 Main metric (macro_f1): 0.8178 Time: 0.99s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.28782209841249223
# Micro Accuracy 0.8918918967247009
# Macro Accuracy 0.8178074955940247
# Macro Precision 0.8295918703079224
# Macro Recall 0.8178074955940247
# Macro F1 0.8178074955940247
#
#
# Training complete in 5m 16s
# Best test main metric: 0.833397

# %%
BEST_MODEL_PATH = './trained_models/{}/{}/best_model.pth'.format(MODEL_NAME, EXPERIMENT_NAME)

# %%
os.makedirs(os.path.dirname(BEST_MODEL_PATH), exist_ok=True)
torch.save(model.state_dict(), BEST_MODEL_PATH)

# %% [markdown]
# ## Evaluación final

# %%
from dataset_modules.common import pil_loader
model.load_state_dict(torch.load(BEST_MODEL_PATH))
model.eval()

metrics = metrics_helper.init_metrics(device, NUM_CLASSES)
tensorboard_transforms = transforms.Compose([
    transforms.ToTensor()
])

total_loss = 0.0

for i, (images, labels, imgs_path) in enumerate(test_loader):
    images = images.to(device)
    labels = labels.to(device)
    
    with torch.no_grad():
        outputs = model(images)
        metrics(outputs, labels)
        
        predictions = torch.argmax(outputs, dim=1)
        loss = criterion(outputs, labels)
        
        total_loss += loss.item() * images.size(0)
        
        for sampleno in range(images.shape[0]):
            if(labels[sampleno] != predictions[sampleno]):
                name = 'Misclasified_Predicted-{}_Classified-{}/{}'.format(classes[predictions[sampleno]], classes[labels[sampleno]], imgs_path[sampleno])
                
                writer.add_image(name, tensorboard_transforms(pil_loader('./dataset_modules/imgs/' + imgs_path[sampleno])))
                writer.flush()
        
total_loss /= dataset_sizes["test"]

metrics_result = metrics.compute()

# %%
macro_metrics = metrics_helper.generate_macro_metrics(metrics_result, total_loss)
per_class_metrics = metrics_helper.generate_per_class_metrics(metrics_result, classes)

macro_metrics.to_csv('./trained_models/{}/{}/best_model_macro_metrics.csv'.format(MODEL_NAME, EXPERIMENT_NAME), index=False)
per_class_metrics.to_csv('./trained_models/{}/{}/best_model_per_class_metrics.csv'.format(MODEL_NAME, EXPERIMENT_NAME), index=False)
# Out:
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2828551525468225
# Micro Accuracy 0.9009009003639221
# Macro Accuracy 0.8333970904350281
# Macro Precision 0.8354515433311462
# Macro Recall 0.8333970904350281
# Macro F1 0.8333970904350281
#
# ------------------------- PER CLASS METRICS -------------------------
#                       class  accuracy  precision    recall        f1
# 0  paragolpe_delantero_roto  0.666667   0.695652  0.666667  0.666667
# 1  paragolpe_delantero_sano  0.853933   0.826087  0.853933  0.853933
# 2    no_paragolpe_delantero  0.979592   0.984615  0.979592  0.979592

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

df_cm = pd.DataFrame(metrics_result['confusion_matrix'], index = classes,
                  columns = classes)

df_cm = df_cm.applymap(lambda x: x.item())

plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap="Blues")
df_cm.to_csv('./trained_models/{}/{}/confusion_matrix.csv'.format(MODEL_NAME, EXPERIMENT_NAME))
