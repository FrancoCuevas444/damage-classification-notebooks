# %% [markdown]
# ## Introducción
#
# Entrenamiento de modelo preentrenado para resolver el problema de predecir el ángulo del auto en base a la imagen.
#
# Fuertemente basado en:
# - https://towardsdatascience.com/a-practical-example-in-transfer-learning-with-pytorch-846bb835f2db
# - https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

# %% [markdown]
# ## Imports

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.datasets as datasets
import torchvision.models as models
import torchvision.transforms as transforms
from torchmetrics import MetricCollection, Accuracy, Precision, Recall, F1, ConfusionMatrix
import pandas as pd
import sklearn
from torch.utils.tensorboard import SummaryWriter

from datetime import datetime
import os

import importlib
import training_helper
from dataset_modules.one_part_dataset import OnePartDataset
import metrics_helper

import dataset_modules.image_preloader as image_preloader

importlib.reload(training_helper)
importlib.reload(metrics_helper)
importlib.reload(image_preloader)
# Out:
# <module 'dataset_modules.image_preloader' from '/clusteruy/home/franco.cuevas/tesis-jupyters-2/dataset_modules/image_preloader.py'>

# %% [markdown]
# ## Variables

# %%
MODEL_NAME = "one_part_model"
EXPERIMENT_NAME = "resnet50_paragolpe_fine_tuning-final"
FEATURE_EXTRACTION = False
parte = "Paragolpe Delantero"

device_string = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(device_string)

if device_string == "cuda":
    print("Usando GPU!")

os.makedirs("./trained_models/{}/{}/".format(MODEL_NAME, EXPERIMENT_NAME), exist_ok=True)
# Out:
# Usando GPU!

# %% [markdown]
# ## Dataset
#
# Se crea un dataset de tipo `ImageFolder` que se toma de la carpeta `dataset`, donde cada subcarpeta es una de las categorías a entrenar.
#
# Automáticamente mapea categorías a números `dataset.class_to_idx`.
#
# Finalmente se hace el split en train y test en 80/20.

# %%
print("start to load dataset")
dataset = OnePartDataset(
    parte,
    transform=transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    preload=True # usar True en cluster
)
print("finish to load dataset")

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size], generator=torch.Generator().manual_seed(42))

classes = dataset.classes

dataset_sizes = {
    'train': len(train_dataset),
    'test': len(test_dataset)
}

print("#TRAIN {} #TEST {}".format(dataset_sizes["train"], dataset_sizes["test"]))
# Out:
# start to load dataset
# ----- CLASS DISTRIBUTION -----
# Class: no_paragolpe_delantero, #916, 55.02%
# Class: paragolpe_delantero_roto, #407, 24.44%
# Class: paragolpe_delantero_sano, #342, 20.54%
# finish to load dataset
# #TRAIN 1332 #TEST 333

# %% [markdown]
# ## Loaders
# Luego, se crean loaders para cada uno de los conjuntos. Los loaders permiten procesar los datos de a batches.

# %%
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True,
    num_workers=0
)

test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=16,
    shuffle=True,
    num_workers=0
)

dataloaders = {
    'train': train_loader,
    'test': test_loader
}

# %% [markdown]
# ## Entrenamiento
#
# En este step se carga el modelo pre-entrenado. Para este ejemplo se utiliza el modelo alexnet por su simplicidad.

# %% [markdown]
# #### ¿Finetuning o Feature extraction?
#
# - **Finetuning:** Consiste en incializar la red con los pesos pre-entrenados, y re-entrenar toda la red (ajustar los parámetros de todas las capas) con el dataset custom.
# - **Feature extraction:** La diferencia con lo anterior es que se congelan las capas convolucionales, de modo que el entrenamiento no las cambie con nuestros datos.
#
# En ambos casos pisamos la capa de **clasificador** por una capa nueva con 8 categorías, porque el modelo pre-entrenado tiene 1000 labels.

# %%
model = models.resnet50(pretrained=True)
NUM_CLASSES = len(classes)

if FEATURE_EXTRACTION:
    for param in model.parameters():
        param.requires_grad = False

model.fc = torch.nn.Linear(2048, NUM_CLASSES)
model = model.to(device)

# Tensorboard metrics writer
writer = SummaryWriter(log_dir='./trained_models/{}/tensorboard/{}'.format(MODEL_NAME, EXPERIMENT_NAME + '-' + datetime.now().strftime("%Y%m%d-%H%M%S")))

# Función de error
criterion = F.cross_entropy

# Optimizador
parameters_to_update = model.parameters()

if FEATURE_EXTRACTION:
    parameters_to_update = model.fc.parameters()

optimizer = optim.SGD(parameters_to_update, lr=0.001)

# %%
model = training_helper.train_model(
    model, 
    criterion, 
    optimizer, 
    dataloaders, 
    dataset_sizes, 
    device, 
    writer, 
    NUM_CLASSES,
    'trained_models/{}/{}'.format(MODEL_NAME, EXPERIMENT_NAME),
    main_metric='macro_f1', 
    num_epochs=25,
    patience=5
)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.9668 Main metric (macro_f1): 0.2487 Time: 9.31s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.9668107233247958
# Micro Accuracy 0.5420420169830322
# Macro Accuracy 0.33820560574531555
# Macro Precision 0.35469189286231995
# Macro Recall 0.33820560574531555
# Macro F1 0.24869465827941895
#
# test Loss: 0.8352 Main metric (macro_f1): 0.2567 Time: 0.96s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8352165157730514
# Micro Accuracy 0.5885885953903198
# Macro Accuracy 0.3361988961696625
# Macro Precision 0.2815040946006775
# Macro Recall 0.3361988961696625
# Macro F1 0.25674962997436523
#
# Epoch 1/24
# ----------
# train Loss: 0.8321 Main metric (macro_f1): 0.3799 Time: 9.47s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8320524918066489
# Micro Accuracy 0.6013513803482056
# Macro Accuracy 0.4172520935535431
# Macro Precision 0.5702274441719055
# Macro Recall 0.4172520935535431
# Macro F1 0.37991535663604736
#
# test Loss: 0.7446 Main metric (macro_f1): 0.5782 Time: 1.00s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7445681394041479
# Micro Accuracy 0.7477477192878723
# Macro Accuracy 0.5960913300514221
# Macro Precision 0.6281036734580994
# Macro Recall 0.5960913300514221
# Macro F1 0.5782259702682495
#
# ES Module Best: 0.7445681394041479, BadEpochs: 0
# Epoch 2/24
# ----------
# train Loss: 0.7086 Main metric (macro_f1): 0.5598 Time: 10.81s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.708550212440548
# Micro Accuracy 0.7019519805908203
# Macro Accuracy 0.562035322189331
# Macro Precision 0.6448662281036377
# Macro Recall 0.562035322189331
# Macro F1 0.5598102807998657
#
# test Loss: 0.6085 Main metric (macro_f1): 0.5398 Time: 1.07s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.608506187483355
# Micro Accuracy 0.7567567825317383
# Macro Accuracy 0.6017875075340271
# Macro Precision 0.79973304271698
# Macro Recall 0.6017875075340271
# Macro F1 0.5397787094116211
#
# ES Module Best: 0.608506187483355, BadEpochs: 0
# Epoch 3/24
# ----------
# train Loss: 0.6192 Main metric (macro_f1): 0.5978 Time: 12.92s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.6192238832021261
# Micro Accuracy 0.7372372150421143
# Macro Accuracy 0.6096775531768799
# Macro Precision 0.6729704737663269
# Macro Recall 0.6096775531768799
# Macro F1 0.597754955291748
#
# test Loss: 0.5284 Main metric (macro_f1): 0.6320 Time: 1.13s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5284238930221077
# Micro Accuracy 0.7807807922363281
# Macro Accuracy 0.6488881707191467
# Macro Precision 0.6820523738861084
# Macro Recall 0.6488881707191467
# Macro F1 0.6319701075553894
#
# ES Module Best: 0.5284238930221077, BadEpochs: 0
# Epoch 4/24
# ----------
# train Loss: 0.5372 Main metric (macro_f1): 0.6690 Time: 15.37s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5372388738769669
# Micro Accuracy 0.7777777910232544
# Macro Accuracy 0.6718091368675232
# Macro Precision 0.7287019491195679
# Macro Recall 0.6718091368675232
# Macro F1 0.6690350770950317
#
# test Loss: 0.4831 Main metric (macro_f1): 0.5984 Time: 1.25s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4830812251603639
# Micro Accuracy 0.7867867946624756
# Macro Accuracy 0.6586146950721741
# Macro Precision 0.7181299924850464
# Macro Recall 0.6586146950721741
# Macro F1 0.5984452962875366
#
# ES Module Best: 0.4830812251603639, BadEpochs: 0
# Epoch 5/24
# ----------
# train Loss: 0.4884 Main metric (macro_f1): 0.6792 Time: 16.69s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4884483061574243
# Micro Accuracy 0.7882882952690125
# Macro Accuracy 0.6877202987670898
# Macro Precision 0.7275675535202026
# Macro Recall 0.6877202987670898
# Macro F1 0.6791673898696899
#
# test Loss: 0.4376 Main metric (macro_f1): 0.6813 Time: 1.27s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.43760654562944407
# Micro Accuracy 0.8108108043670654
# Macro Accuracy 0.6971187591552734
# Macro Precision 0.7393428087234497
# Macro Recall 0.6971187591552734
# Macro F1 0.6812602877616882
#
# ES Module Best: 0.43760654562944407, BadEpochs: 0
# Epoch 6/24
# ----------
# train Loss: 0.4485 Main metric (macro_f1): 0.7619 Time: 17.72s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4485303641439558
# Micro Accuracy 0.8340840935707092
# Macro Accuracy 0.7551742196083069
# Macro Precision 0.7904065251350403
# Macro Recall 0.7551742196083069
# Macro F1 0.7619321346282959
#
# test Loss: 0.4200 Main metric (macro_f1): 0.6549 Time: 1.25s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.41999687276802977
# Micro Accuracy 0.804804801940918
# Macro Accuracy 0.6876412034034729
# Macro Precision 0.7458455562591553
# Macro Recall 0.6876412034034729
# Macro F1 0.6548742055892944
#
# ES Module Best: 0.41999687276802977, BadEpochs: 0
# Epoch 7/24
# ----------
# train Loss: 0.4135 Main metric (macro_f1): 0.7574 Time: 18.34s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.41352311644826206
# Micro Accuracy 0.8333333134651184
# Macro Accuracy 0.754374086856842
# Macro Precision 0.789006769657135
# Macro Recall 0.754374086856842
# Macro F1 0.7573590278625488
#
# test Loss: 0.3935 Main metric (macro_f1): 0.7107 Time: 1.26s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3934819260696033
# Micro Accuracy 0.8138138055801392
# Macro Accuracy 0.71003258228302
# Macro Precision 0.7170538902282715
# Macro Recall 0.71003258228302
# Macro F1 0.7107436656951904
#
# ES Module Best: 0.3934819260696033, BadEpochs: 0
# Epoch 8/24
# ----------
# train Loss: 0.3891 Main metric (macro_f1): 0.7935 Time: 18.36s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.38909035589959884
# Micro Accuracy 0.8521021008491516
# Macro Accuracy 0.7888378500938416
# Macro Precision 0.8020869493484497
# Macro Recall 0.7888378500938416
# Macro F1 0.7934948801994324
#
# test Loss: 0.3857 Main metric (macro_f1): 0.6727 Time: 1.24s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.38571101955107384
# Micro Accuracy 0.8138138055801392
# Macro Accuracy 0.6997585892677307
# Macro Precision 0.7599546313285828
# Macro Recall 0.6997585892677307
# Macro F1 0.6727251410484314
#
# ES Module Best: 0.38571101955107384, BadEpochs: 0
# Epoch 9/24
# ----------
# train Loss: 0.3593 Main metric (macro_f1): 0.8044 Time: 19.45s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.35934509744157306
# Micro Accuracy 0.8648648858070374
# Macro Accuracy 0.8003823161125183
# Macro Precision 0.8216438293457031
# Macro Recall 0.8003823161125183
# Macro F1 0.8043878078460693
#
# test Loss: 0.3734 Main metric (macro_f1): 0.6920 Time: 1.19s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.37336829904321434
# Micro Accuracy 0.8078078031539917
# Macro Accuracy 0.6970474720001221
# Macro Precision 0.7041880488395691
# Macro Recall 0.6970474720001221
# Macro F1 0.6920022964477539
#
# ES Module Best: 0.37336829904321434, BadEpochs: 0
# Epoch 10/24
# ----------
# train Loss: 0.3368 Main metric (macro_f1): 0.8474 Time: 20.19s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.33682027065360154
# Micro Accuracy 0.8918918967247009
# Macro Accuracy 0.8427435755729675
# Macro Precision 0.8567317724227905
# Macro Recall 0.8427435755729675
# Macro F1 0.8473734855651855
#
# test Loss: 0.3683 Main metric (macro_f1): 0.7135 Time: 1.19s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.36827652250324283
# Micro Accuracy 0.8228228092193604
# Macro Accuracy 0.7205206155776978
# Macro Precision 0.730404257774353
# Macro Recall 0.7205206155776978
# Macro F1 0.7135471701622009
#
# ES Module Best: 0.36827652250324283, BadEpochs: 0
# Epoch 11/24
# ----------
# train Loss: 0.3228 Main metric (macro_f1): 0.8607 Time: 18.58s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3227545123200517
# Micro Accuracy 0.9001501798629761
# Macro Accuracy 0.855462908744812
# Macro Precision 0.8704699277877808
# Macro Recall 0.855462908744812
# Macro F1 0.8607112169265747
#
# test Loss: 0.3582 Main metric (macro_f1): 0.7094 Time: 1.18s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.35815855278983133
# Micro Accuracy 0.8138138055801392
# Macro Accuracy 0.7093904614448547
# Macro Precision 0.7160400152206421
# Macro Recall 0.7093904614448547
# Macro F1 0.7094083428382874
#
# ES Module Best: 0.35815855278983133, BadEpochs: 0
# Epoch 12/24
# ----------
# train Loss: 0.2935 Main metric (macro_f1): 0.8767 Time: 18.94s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2935095779351644
# Micro Accuracy 0.9114114046096802
# Macro Accuracy 0.8723815679550171
# Macro Precision 0.8815237283706665
# Macro Recall 0.8723815679550171
# Macro F1 0.8767459392547607
#
# test Loss: 0.3528 Main metric (macro_f1): 0.7251 Time: 2.27s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3527595185123764
# Micro Accuracy 0.8228228092193604
# Macro Accuracy 0.7262997031211853
# Macro Precision 0.7245637774467468
# Macro Recall 0.7262997031211853
# Macro F1 0.7250829339027405
#
# ES Module Best: 0.3527595185123764, BadEpochs: 0
# Epoch 13/24
# ----------
# train Loss: 0.2796 Main metric (macro_f1): 0.8721 Time: 17.43s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2796045262534339
# Micro Accuracy 0.9091591835021973
# Macro Accuracy 0.8685153126716614
# Macro Precision 0.8761934638023376
# Macro Recall 0.8685153126716614
# Macro F1 0.8720893263816833
#
# test Loss: 0.3496 Main metric (macro_f1): 0.7269 Time: 1.21s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.34960408522202086
# Micro Accuracy 0.8258258104324341
# Macro Accuracy 0.7289395928382874
# Macro Precision 0.730987012386322
# Macro Recall 0.7289395928382874
# Macro F1 0.726861298084259
#
# ES Module Best: 0.34960408522202086, BadEpochs: 0
# Epoch 14/24
# ----------
# train Loss: 0.2532 Main metric (macro_f1): 0.9107 Time: 18.61s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2532476404676208
# Micro Accuracy 0.93543541431427
# Macro Accuracy 0.9085363149642944
# Macro Precision 0.9133319854736328
# Macro Recall 0.9085363149642944
# Macro F1 0.910686194896698
#
# test Loss: 0.3459 Main metric (macro_f1): 0.7382 Time: 2.02s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.34585852263210054
# Micro Accuracy 0.8318318128585815
# Macro Accuracy 0.739356279373169
# Macro Precision 0.7402588129043579
# Macro Recall 0.739356279373169
# Macro F1 0.7382055521011353
#
# ES Module Best: 0.34585852263210054, BadEpochs: 0
# Epoch 15/24
# ----------
# train Loss: 0.2348 Main metric (macro_f1): 0.9097 Time: 19.00s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.23484847728196565
# Micro Accuracy 0.93543541431427
# Macro Accuracy 0.9092755317687988
# Macro Precision 0.9105074405670166
# Macro Recall 0.9092755317687988
# Macro F1 0.9097453951835632
#
# test Loss: 0.3456 Main metric (macro_f1): 0.7406 Time: 1.19s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3456255854429067
# Micro Accuracy 0.8318318128585815
# Macro Accuracy 0.7419247031211853
# Macro Precision 0.739428699016571
# Macro Recall 0.7419247031211853
# Macro F1 0.7406286597251892
#
# ES Module Best: 0.3456255854429067, BadEpochs: 0
# Epoch 16/24
# ----------
# train Loss: 0.2133 Main metric (macro_f1): 0.9291 Time: 19.34s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2133127104591679
# Micro Accuracy 0.9504504799842834
# Macro Accuracy 0.9286357164382935
# Macro Precision 0.9298063516616821
# Macro Recall 0.9286357164382935
# Macro F1 0.9291386604309082
#
# test Loss: 0.3415 Main metric (macro_f1): 0.7446 Time: 1.78s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3415306133998407
# Micro Accuracy 0.8348348140716553
# Macro Accuracy 0.7458487749099731
# Macro Precision 0.7440397143363953
# Macro Recall 0.7458487749099731
# Macro F1 0.7445796728134155
#
# ES Module Best: 0.3415306133998407, BadEpochs: 0
# Epoch 17/24
# ----------
# train Loss: 0.1943 Main metric (macro_f1): 0.9407 Time: 18.40s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.19433403784806305
# Micro Accuracy 0.957207202911377
# Macro Accuracy 0.9406982064247131
# Macro Precision 0.941167950630188
# Macro Recall 0.9406982064247131
# Macro F1 0.9406546354293823
#
# test Loss: 0.3436 Main metric (macro_f1): 0.7430 Time: 1.20s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3436493067233054
# Micro Accuracy 0.8348348140716553
# Macro Accuracy 0.7445645928382874
# Macro Precision 0.7442391514778137
# Macro Recall 0.7445645928382874
# Macro F1 0.7429891228675842
#
# ES Module Best: 0.3415306133998407, BadEpochs: 1
# Epoch 18/24
# ----------
# train Loss: 0.1700 Main metric (macro_f1): 0.9607 Time: 19.35s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.1699700944416516
# Micro Accuracy 0.9729729890823364
# Macro Accuracy 0.9606542587280273
# Macro Precision 0.9608058929443359
# Macro Recall 0.9606542587280273
# Macro F1 0.9607194662094116
#
# test Loss: 0.3460 Main metric (macro_f1): 0.7283 Time: 2.30s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.34603527268847906
# Micro Accuracy 0.8288288116455078
# Macro Accuracy 0.7299981117248535
# Macro Precision 0.7330917119979858
# Macro Recall 0.7299981117248535
# Macro F1 0.7283202409744263
#
# ES Module Best: 0.3415306133998407, BadEpochs: 2
# Epoch 19/24
# ----------
# train Loss: 0.1573 Main metric (macro_f1): 0.9595 Time: 19.19s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.15730648454245147
# Micro Accuracy 0.9707207083702087
# Macro Accuracy 0.9576602578163147
# Macro Precision 0.9614983201026917
# Macro Recall 0.9576602578163147
# Macro F1 0.9595092535018921
#
# test Loss: 0.3462 Main metric (macro_f1): 0.7270 Time: 1.26s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3461575677265992
# Micro Accuracy 0.8288288116455078
# Macro Accuracy 0.7293559908866882
# Macro Precision 0.7334271669387817
# Macro Recall 0.7293559908866882
# Macro F1 0.7269691824913025
#
# ES Module Best: 0.3415306133998407, BadEpochs: 3
# Epoch 20/24
# ----------
# train Loss: 0.1399 Main metric (macro_f1): 0.9754 Time: 19.30s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.13985169958602917
# Micro Accuracy 0.9812312126159668
# Macro Accuracy 0.9739086031913757
# Macro Precision 0.9770398736000061
# Macro Recall 0.9739086031913757
# Macro F1 0.9754419326782227
#
# test Loss: 0.3496 Main metric (macro_f1): 0.7395 Time: 1.33s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.34955314197787296
# Micro Accuracy 0.8348348140716553
# Macro Accuracy 0.7404147386550903
# Macro Precision 0.7430857419967651
# Macro Recall 0.7404147386550903
# Macro F1 0.7394670248031616
#
# ES Module Best: 0.3415306133998407, BadEpochs: 4
# Epoch 21/24
# ----------
# train Loss: 0.1305 Main metric (macro_f1): 0.9760 Time: 19.60s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.13050001479304946
# Micro Accuracy 0.9812312126159668
# Macro Accuracy 0.9764508008956909
# Macro Precision 0.9755777716636658
# Macro Recall 0.9764508008956909
# Macro F1 0.9760093092918396
#
# test Loss: 0.3536 Main metric (macro_f1): 0.7376 Time: 1.38s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.35358270940121944
# Micro Accuracy 0.8318318128585815
# Macro Accuracy 0.739356279373169
# Macro Precision 0.739395022392273
# Macro Recall 0.739356279373169
# Macro F1 0.7376068830490112
#
# ES Module Best: 0.3415306133998407, BadEpochs: 5
# Early stopping... Best Epoch: 16
# Training complete in 6m 50s
# Best test epoch loss: 0.341531
# Best test main metric: 0.744580

# %%
BEST_MODEL_PATH = './trained_models/{}/{}/best_model.pth'.format(MODEL_NAME, EXPERIMENT_NAME)
os.makedirs(os.path.dirname(BEST_MODEL_PATH), exist_ok=True)
torch.save(model.state_dict(), BEST_MODEL_PATH)

# %% [markdown]
# ## Evaluación final

# %%
from dataset_modules.common import pil_loader
model.load_state_dict(torch.load(BEST_MODEL_PATH))
model.eval()

metrics = metrics_helper.init_metrics(device, NUM_CLASSES)
tensorboard_transforms = transforms.Compose([
    transforms.ToTensor()
])

total_loss = 0.0

for i, (images, labels, imgs_path) in enumerate(test_loader):
    images = images.to(device)
    labels = labels.to(device)
    
    with torch.no_grad():
        outputs = model(images)
        metrics(outputs, labels)
        
        predictions = torch.argmax(outputs, dim=1)
        loss = criterion(outputs, labels)
        
        total_loss += loss.item() * images.size(0)
        
        for sampleno in range(images.shape[0]):
            if(labels[sampleno] != predictions[sampleno]):
                name = 'Misclasified_Predicted-{}_Classified-{}/{}'.format(classes[predictions[sampleno]], classes[labels[sampleno]], imgs_path[sampleno])
                
                writer.add_image(name, tensorboard_transforms(pil_loader('./dataset_modules/imgs/' + imgs_path[sampleno])))
                writer.flush()
        
total_loss /= dataset_sizes["test"]

metrics_result = metrics.compute()

# %%
macro_metrics = metrics_helper.generate_macro_metrics(metrics_result, total_loss)
per_class_metrics = metrics_helper.generate_per_class_metrics(metrics_result, classes)

macro_metrics.to_csv('./trained_models/{}/{}/best_model_macro_metrics.csv'.format(MODEL_NAME, EXPERIMENT_NAME), index=False)
per_class_metrics.to_csv('./trained_models/{}/{}/best_model_per_class_metrics.csv'.format(MODEL_NAME, EXPERIMENT_NAME), index=False)
# Out:
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3592681154474482
# Micro Accuracy 0.8468468189239502
# Macro Accuracy 0.7669792175292969
# Macro Precision 0.7657854557037354
# Macro Recall 0.7669792175292969
# Macro F1 0.7640835642814636
#
# ------------------------- PER CLASS METRICS -------------------------
#                       class  precision    recall        f1
# 0  paragolpe_delantero_roto   0.647059  0.753425  0.696203
# 1  paragolpe_delantero_sano   0.660714  0.578125  0.616667
# 2    no_paragolpe_delantero   0.989583  0.969388  0.979382

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

df_cm = pd.DataFrame(metrics_result['confusion_matrix'], index = classes,
                  columns = classes)

df_cm = df_cm.applymap(lambda x: x.item())

plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap="Blues")
df_cm.to_csv('./trained_models/{}/{}/confusion_matrix.csv'.format(MODEL_NAME, EXPERIMENT_NAME))
