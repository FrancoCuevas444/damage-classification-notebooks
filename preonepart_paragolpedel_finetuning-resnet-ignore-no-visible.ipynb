# %% [markdown]
# ## Introducción
#
# Entrenamiento de modelo preentrenado para resolver el problema de predecir el ángulo del auto en base a la imagen.
#
# Fuertemente basado en:
# - https://towardsdatascience.com/a-practical-example-in-transfer-learning-with-pytorch-846bb835f2db
# - https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

# %% [markdown]
# ## Imports

# %%
import torch
import dataset_modules.image_preloader as image_preloader
import main
import importlib
import dataset_modules.preloaded_one_part_dataset as popd
import training_helper
importlib.reload(training_helper)
importlib.reload(main)
importlib.reload(popd)
# Out:
# <module 'dataset_modules.preloaded_one_part_dataset' from '/clusteruy/home/franco.cuevas/tesis-jupyters-2/dataset_modules/preloaded_one_part_dataset.py'>

# %% [markdown]
# ## Variables

# %%
FEATURE_EXTRACTION = False

device_string = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(device_string)

if device_string == "cuda":
    print("Usando GPU!")
# Out:
# Usando GPU!

# %%
# preload images
preloaded_images = image_preloader.preload_images(
        images_folder='./dataset_modules/imgs/', 
        state_file='./dataset_modules/state.json', 
        resize_to=224
)
# Out:
# Started to preload images...
# Image preloading complete in 2m 18s
# The preloaded images use 0.07039642333984375MB of memory

# %%
import sklearn
import dataset_modules.common as common
import dataset_modules.preloaded_one_part_dataset as popd
importlib.reload(popd)
importlib.reload(common)
part = "Paragolpe Delantero"

dataset = popd.PreloadedOnePartDataset(
    part,
    preloaded_images,
    remove_not_visible=True
)

print(len(dataset.samples))

y = [y_s for (_,y_s,_) in dataset.samples]
balanced_weights = sklearn.utils.class_weight.compute_class_weight('balanced', classes=[0,1], y=y)
# Out:
# ----- CLASS DISTRIBUTION -----
# Class: paragolpe_delantero_roto, #407, 54.34%
# Class: paragolpe_delantero_sano, #342, 45.66%
# 749
# array([0.92014742, 1.09502924])

# %%
part = "Paragolpe Delantero"
MODEL_NAME = "one_part_model"
EXPERIMENT_NAME = "resnet50_finetuning-paragolpedel-ignore-notvisible"

main.train_one_part_model(
    part, 
    preloaded_images, 
    MODEL_NAME, 
    EXPERIMENT_NAME, 
    device, 
    feature_extraction=False,
    train_ratio=0.8,
    random_state=42,
    num_epochs=40,
    remove_not_visible=True#,
    #visibility_file="./dataset_modules/analisis_manual_paragolpe.csv"
)
# Out:
# ----- CLASS DISTRIBUTION -----
# Class: paragolpe_delantero_roto, #407, 54.34%
# Class: paragolpe_delantero_sano, #342, 45.66%
# #TRAIN 599 #TEST 150
# Epoch 0/39
# ----------
# train Loss: 0.6942 Main metric (macro_f1): 0.4839 Time: 9.88s
# test Loss: 0.6964 Main metric (macro_f1): 0.4533 Time: 0.50s
# Epoch 1/39
# ----------
# train Loss: 0.6652 Main metric (macro_f1): 0.5222 Time: 4.38s
# test Loss: 0.6711 Main metric (macro_f1): 0.5848 Time: 0.50s
# ES Module Best: 0.6711467305819193, BadEpochs: 0
# Epoch 2/39
# ----------
# train Loss: 0.6567 Main metric (macro_f1): 0.5573 Time: 4.40s
# test Loss: 0.6650 Main metric (macro_f1): 0.5530 Time: 0.50s
# ES Module Best: 0.6649955995877583, BadEpochs: 0
# Epoch 3/39
# ----------
# train Loss: 0.6388 Main metric (macro_f1): 0.6303 Time: 4.39s
# test Loss: 0.6642 Main metric (macro_f1): 0.5251 Time: 0.50s
# ES Module Best: 0.6641551661491394, BadEpochs: 0
# Epoch 4/39
# ----------
# train Loss: 0.6213 Main metric (macro_f1): 0.6568 Time: 4.40s
# test Loss: 0.6611 Main metric (macro_f1): 0.5098 Time: 0.50s
# ES Module Best: 0.6611202112833658, BadEpochs: 0
# Epoch 5/39
# ----------
# train Loss: 0.6015 Main metric (macro_f1): 0.6929 Time: 4.40s
# test Loss: 0.6492 Main metric (macro_f1): 0.5660 Time: 0.50s
# ES Module Best: 0.6492032718658447, BadEpochs: 0
# Epoch 6/39
# ----------
# train Loss: 0.6004 Main metric (macro_f1): 0.6824 Time: 4.37s
# test Loss: 0.6460 Main metric (macro_f1): 0.5660 Time: 0.50s
# ES Module Best: 0.6460104401906331, BadEpochs: 0
# Epoch 7/39
# ----------
# train Loss: 0.5669 Main metric (macro_f1): 0.7595 Time: 4.36s
# test Loss: 0.6346 Main metric (macro_f1): 0.6089 Time: 0.49s
# ES Module Best: 0.6345851198832194, BadEpochs: 0
# Epoch 8/39
# ----------
# train Loss: 0.5412 Main metric (macro_f1): 0.7950 Time: 4.37s
# test Loss: 0.6147 Main metric (macro_f1): 0.7266 Time: 0.50s
# ES Module Best: 0.6146751991907755, BadEpochs: 0
# Epoch 9/39
# ----------
# train Loss: 0.5220 Main metric (macro_f1): 0.8050 Time: 4.38s
# test Loss: 0.6182 Main metric (macro_f1): 0.6618 Time: 0.50s
# ES Module Best: 0.6146751991907755, BadEpochs: 1
# Epoch 10/39
# ----------
# train Loss: 0.5011 Main metric (macro_f1): 0.8138 Time: 4.38s
# test Loss: 0.6198 Main metric (macro_f1): 0.6457 Time: 0.50s
# ES Module Best: 0.6146751991907755, BadEpochs: 2
# Epoch 11/39
# ----------
# train Loss: 0.4598 Main metric (macro_f1): 0.8779 Time: 4.37s
# test Loss: 0.6750 Main metric (macro_f1): 0.4779 Time: 0.50s
# ES Module Best: 0.6146751991907755, BadEpochs: 3
# Epoch 12/39
# ----------
# train Loss: 0.4376 Main metric (macro_f1): 0.8508 Time: 4.37s
# test Loss: 0.6073 Main metric (macro_f1): 0.6421 Time: 0.50s
# ES Module Best: 0.6072665405273437, BadEpochs: 0
# Epoch 13/39
# ----------
# train Loss: 0.3997 Main metric (macro_f1): 0.9006 Time: 4.38s
# test Loss: 0.5926 Main metric (macro_f1): 0.7264 Time: 0.51s
# ES Module Best: 0.5926241230964661, BadEpochs: 0
# Epoch 14/39
# ----------
# train Loss: 0.3694 Main metric (macro_f1): 0.9151 Time: 4.37s
# test Loss: 0.5902 Main metric (macro_f1): 0.7118 Time: 0.50s
# ES Module Best: 0.5902303655942281, BadEpochs: 0
# Epoch 15/39
# ----------
# train Loss: 0.3313 Main metric (macro_f1): 0.9511 Time: 4.39s
# test Loss: 0.6178 Main metric (macro_f1): 0.6185 Time: 0.50s
# ES Module Best: 0.5902303655942281, BadEpochs: 1
# Epoch 16/39
# ----------
# train Loss: 0.3215 Main metric (macro_f1): 0.9236 Time: 4.40s
# test Loss: 0.6054 Main metric (macro_f1): 0.6440 Time: 0.50s
# ES Module Best: 0.5902303655942281, BadEpochs: 2
# Epoch 17/39
# ----------
# train Loss: 0.2675 Main metric (macro_f1): 0.9797 Time: 4.38s
# test Loss: 0.5998 Main metric (macro_f1): 0.6397 Time: 0.50s
# ES Module Best: 0.5902303655942281, BadEpochs: 3
# Epoch 18/39
# ----------
# train Loss: 0.2566 Main metric (macro_f1): 0.9578 Time: 4.38s
# test Loss: 0.6060 Main metric (macro_f1): 0.6528 Time: 0.49s
# ES Module Best: 0.5902303655942281, BadEpochs: 4
# Epoch 19/39
# ----------
# train Loss: 0.2357 Main metric (macro_f1): 0.9661 Time: 4.38s
# test Loss: 0.6061 Main metric (macro_f1): 0.6465 Time: 0.50s
# ES Module Best: 0.5902303655942281, BadEpochs: 5
# Early stopping... Best Epoch: 14
# Training complete in 1m 47s
# Best test epoch loss: 0.590230
# Best test main metric: 0.726557
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5902304045359293
# Micro Accuracy 0.7133333086967468
# Macro Accuracy 0.712482213973999
# Macro Precision 0.7162896394729614
# Macro Recall 0.712482213973999
# Macro F1 0.7117833495140076
#
# ------------------------- PER CLASS METRICS -------------------------
#                       class  precision    recall        f1
# 0  paragolpe_delantero_roto   0.738462  0.648649  0.690647
# 1  paragolpe_delantero_sano   0.694118  0.776316  0.732919

# %%
EXPERIMENT_NAME = "resnet50_finetuning-paragolpedel-ignore-notvisible-ignorelow"

main.train_one_part_model(
    part, 
    preloaded_images, 
    MODEL_NAME, 
    EXPERIMENT_NAME, 
    device, 
    feature_extraction=False,
    train_ratio=0.8,
    random_state=42,
    num_epochs=40,
    remove_not_visible=True,
    visibility_file="./dataset_modules/analisis_manual_paragolpe.csv"
)
# Out:
# ----- CLASS DISTRIBUTION -----
# Class: paragolpe_delantero_sano, #475, 63.42%
# Class: paragolpe_delantero_roto, #274, 36.58%
# #TRAIN 599 #TEST 150
# Epoch 0/39
# ----------
# train Loss: 0.6616 Main metric (macro_f1): 0.4277 Time: 4.38s
# test Loss: 0.6299 Main metric (macro_f1): 0.4128 Time: 0.51s
# Epoch 1/39
# ----------
# train Loss: 0.6478 Main metric (macro_f1): 0.4502 Time: 4.38s
# test Loss: 0.6169 Main metric (macro_f1): 0.4870 Time: 0.51s
# ES Module Best: 0.6168763868014018, BadEpochs: 0
# Epoch 2/39
# ----------
# train Loss: 0.6186 Main metric (macro_f1): 0.4993 Time: 4.39s
# test Loss: 0.5987 Main metric (macro_f1): 0.4545 Time: 0.50s
# ES Module Best: 0.5987326081593831, BadEpochs: 0
# Epoch 3/39
# ----------
# train Loss: 0.6038 Main metric (macro_f1): 0.5208 Time: 4.39s
# test Loss: 0.5982 Main metric (macro_f1): 0.6387 Time: 0.50s
# ES Module Best: 0.5982000637054443, BadEpochs: 0
# Epoch 4/39
# ----------
# train Loss: 0.5832 Main metric (macro_f1): 0.6192 Time: 4.40s
# test Loss: 0.5782 Main metric (macro_f1): 0.5974 Time: 0.50s
# ES Module Best: 0.5781668543815612, BadEpochs: 0
# Epoch 5/39
# ----------
# train Loss: 0.5557 Main metric (macro_f1): 0.6307 Time: 4.41s
# test Loss: 0.5666 Main metric (macro_f1): 0.6115 Time: 0.50s
# ES Module Best: 0.5665927561124166, BadEpochs: 0
# Epoch 6/39
# ----------
# train Loss: 0.5406 Main metric (macro_f1): 0.6662 Time: 4.37s
# test Loss: 0.5606 Main metric (macro_f1): 0.6587 Time: 0.51s
# ES Module Best: 0.5605922913551331, BadEpochs: 0
# Epoch 7/39
# ----------
# train Loss: 0.5147 Main metric (macro_f1): 0.7410 Time: 4.39s
# test Loss: 0.5412 Main metric (macro_f1): 0.6387 Time: 0.51s
# ES Module Best: 0.5411743259429932, BadEpochs: 0
# Epoch 8/39
# ----------
# train Loss: 0.4886 Main metric (macro_f1): 0.7527 Time: 4.38s
# test Loss: 0.5316 Main metric (macro_f1): 0.6950 Time: 0.50s
# ES Module Best: 0.5316332721710205, BadEpochs: 0
# Epoch 9/39
# ----------
# train Loss: 0.4556 Main metric (macro_f1): 0.8021 Time: 4.39s
# test Loss: 0.5184 Main metric (macro_f1): 0.6950 Time: 0.50s
# ES Module Best: 0.5184393123785654, BadEpochs: 0
# Epoch 10/39
# ----------
# train Loss: 0.4530 Main metric (macro_f1): 0.7925 Time: 4.38s
# test Loss: 0.5141 Main metric (macro_f1): 0.6993 Time: 0.50s
# ES Module Best: 0.5141064421335856, BadEpochs: 0
# Epoch 11/39
# ----------
# train Loss: 0.4051 Main metric (macro_f1): 0.8471 Time: 4.39s
# test Loss: 0.5020 Main metric (macro_f1): 0.7055 Time: 0.50s
# ES Module Best: 0.5019881693522136, BadEpochs: 0
# Epoch 12/39
# ----------
# train Loss: 0.3653 Main metric (macro_f1): 0.8871 Time: 4.39s
# test Loss: 0.4920 Main metric (macro_f1): 0.7004 Time: 0.51s
# ES Module Best: 0.49202497879664103, BadEpochs: 0
# Epoch 13/39
# ----------
# train Loss: 0.3399 Main metric (macro_f1): 0.8804 Time: 4.40s
# test Loss: 0.4870 Main metric (macro_f1): 0.7040 Time: 0.50s
# ES Module Best: 0.48697521130243937, BadEpochs: 0
# Epoch 14/39
# ----------
# train Loss: 0.3080 Main metric (macro_f1): 0.9230 Time: 4.39s
# test Loss: 0.4803 Main metric (macro_f1): 0.7040 Time: 0.50s
# ES Module Best: 0.4802987273534139, BadEpochs: 0
# Epoch 15/39
# ----------
# train Loss: 0.2708 Main metric (macro_f1): 0.9318 Time: 4.38s
# test Loss: 0.4696 Main metric (macro_f1): 0.7147 Time: 0.50s
# ES Module Best: 0.4696407985687256, BadEpochs: 0
# Epoch 16/39
# ----------
# train Loss: 0.2409 Main metric (macro_f1): 0.9619 Time: 4.39s
# test Loss: 0.4733 Main metric (macro_f1): 0.7004 Time: 0.50s
# ES Module Best: 0.4696407985687256, BadEpochs: 1
# Epoch 17/39
# ----------
# train Loss: 0.2269 Main metric (macro_f1): 0.9416 Time: 4.47s
# test Loss: 0.4701 Main metric (macro_f1): 0.6943 Time: 0.51s
# ES Module Best: 0.4696407985687256, BadEpochs: 2
# Epoch 18/39
# ----------
# train Loss: 0.1947 Main metric (macro_f1): 0.9618 Time: 4.40s
# test Loss: 0.4647 Main metric (macro_f1): 0.7055 Time: 0.50s
# ES Module Best: 0.4647096753120422, BadEpochs: 0
# Epoch 19/39
# ----------
# train Loss: 0.1828 Main metric (macro_f1): 0.9710 Time: 4.37s
# test Loss: 0.4588 Main metric (macro_f1): 0.7085 Time: 0.51s
# ES Module Best: 0.4587914228439331, BadEpochs: 0
# Epoch 20/39
# ----------
# train Loss: 0.1476 Main metric (macro_f1): 0.9820 Time: 4.37s
# test Loss: 0.4580 Main metric (macro_f1): 0.7165 Time: 0.50s
# ES Module Best: 0.45798377056916556, BadEpochs: 0
# Epoch 21/39
# ----------
# train Loss: 0.1318 Main metric (macro_f1): 0.9838 Time: 4.38s
# test Loss: 0.4580 Main metric (macro_f1): 0.7315 Time: 0.50s
# ES Module Best: 0.45798377056916556, BadEpochs: 1
# Epoch 22/39
# ----------
# train Loss: 0.1170 Main metric (macro_f1): 0.9857 Time: 4.38s
# test Loss: 0.4600 Main metric (macro_f1): 0.7085 Time: 0.50s
# ES Module Best: 0.45798377056916556, BadEpochs: 2
# Epoch 23/39
# ----------
# train Loss: 0.1050 Main metric (macro_f1): 0.9946 Time: 4.42s
# test Loss: 0.4635 Main metric (macro_f1): 0.7210 Time: 0.50s
# ES Module Best: 0.45798377056916556, BadEpochs: 3
# Epoch 24/39
# ----------
# train Loss: 0.0958 Main metric (macro_f1): 0.9874 Time: 4.39s
# test Loss: 0.4581 Main metric (macro_f1): 0.7189 Time: 0.50s
# ES Module Best: 0.45798377056916556, BadEpochs: 4
# Epoch 25/39
# ----------
# train Loss: 0.0807 Main metric (macro_f1): 1.0000 Time: 4.38s
# test Loss: 0.4606 Main metric (macro_f1): 0.7291 Time: 0.50s
# ES Module Best: 0.45798377056916556, BadEpochs: 5
# Early stopping... Best Epoch: 20
# Training complete in 2m 16s
# Best test epoch loss: 0.457984
# Best test main metric: 0.731484
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4579837656021118
# Micro Accuracy 0.7799999713897705
# Macro Accuracy 0.7002376914024353
# Macro Precision 0.7959601879119873
# Macro Recall 0.7002376914024353
# Macro F1 0.7164785861968994
#
# ------------------------- PER CLASS METRICS -------------------------
#                       class  precision    recall        f1
# 0  paragolpe_delantero_roto   0.821429  0.450980  0.582278
# 1  paragolpe_delantero_sano   0.770492  0.949495  0.850679

# %%
dataset = popd.PreloadedOnePartDataset(
    part,
    preloaded_images,
    remove_not_visible=True,
    visibility_file="./dataset_modules/analisis_manual_paragolpe.csv"
)

print(len(dataset.samples))

y = [y_s for (_,y_s,_) in dataset.samples]
balanced_weights = sklearn.utils.class_weight.compute_class_weight('balanced', classes=[0,1], y=y)
balanced_weights = torch.tensor(balanced_weights,dtype=torch.float)
print(balanced_weights)
# Out:
# ----- CLASS DISTRIBUTION -----
# Class: paragolpe_delantero_sano, #475, 63.42%
# Class: paragolpe_delantero_roto, #274, 36.58%
# 749
# tensor([1.3668, 0.7884])

# %%
EXPERIMENT_NAME = "resnet50_finetuning-paragolpedel-ignore-notvisible-ignorelow-balanced"

main.train_one_part_model(
    part, 
    preloaded_images, 
    MODEL_NAME, 
    EXPERIMENT_NAME, 
    device, 
    feature_extraction=False,
    train_ratio=0.8,
    random_state=42,
    num_epochs=40,
    remove_not_visible=True,
    visibility_file="./dataset_modules/analisis_manual_paragolpe.csv",
    class_weights=balanced_weights
)
# Out:
# ----- CLASS DISTRIBUTION -----
# Class: paragolpe_delantero_sano, #475, 63.42%
# Class: paragolpe_delantero_roto, #274, 36.58%
# #TRAIN 599 #TEST 150
# Epoch 0/39
# ----------
# train Loss: 0.6991 Main metric (macro_f1): 0.5419 Time: 4.37s
# test Loss: 0.7213 Main metric (macro_f1): 0.2650 Time: 0.50s
# Epoch 1/39
# ----------
# train Loss: 0.6867 Main metric (macro_f1): 0.5353 Time: 4.37s
# test Loss: 0.6879 Main metric (macro_f1): 0.4530 Time: 0.50s
# ES Module Best: 0.6879219206174215, BadEpochs: 0
# Epoch 2/39
# ----------
# train Loss: 0.6576 Main metric (macro_f1): 0.6290 Time: 4.38s
# test Loss: 0.6580 Main metric (macro_f1): 0.5711 Time: 0.50s
# ES Module Best: 0.6580295205116272, BadEpochs: 0
# Epoch 3/39
# ----------
# train Loss: 0.6403 Main metric (macro_f1): 0.6743 Time: 4.38s
# test Loss: 0.6626 Main metric (macro_f1): 0.5375 Time: 0.50s
# ES Module Best: 0.6580295205116272, BadEpochs: 1
# Epoch 4/39
# ----------
# train Loss: 0.6198 Main metric (macro_f1): 0.6784 Time: 4.39s
# test Loss: 0.6292 Main metric (macro_f1): 0.6197 Time: 0.50s
# ES Module Best: 0.6292076714833578, BadEpochs: 0
# Epoch 5/39
# ----------
# train Loss: 0.6017 Main metric (macro_f1): 0.7208 Time: 4.47s
# test Loss: 0.6173 Main metric (macro_f1): 0.6703 Time: 0.50s
# ES Module Best: 0.6172840142250061, BadEpochs: 0
# Epoch 6/39
# ----------
# train Loss: 0.5755 Main metric (macro_f1): 0.7625 Time: 4.38s
# test Loss: 0.6342 Main metric (macro_f1): 0.5375 Time: 0.50s
# ES Module Best: 0.6172840142250061, BadEpochs: 1
# Epoch 7/39
# ----------
# train Loss: 0.5522 Main metric (macro_f1): 0.7835 Time: 4.39s
# test Loss: 0.5912 Main metric (macro_f1): 0.6940 Time: 0.50s
# ES Module Best: 0.5911743855476379, BadEpochs: 0
# Epoch 8/39
# ----------
# train Loss: 0.5202 Main metric (macro_f1): 0.8188 Time: 4.40s
# test Loss: 0.5738 Main metric (macro_f1): 0.7022 Time: 0.50s
# ES Module Best: 0.5737995862960815, BadEpochs: 0
# Epoch 9/39
# ----------
# train Loss: 0.4952 Main metric (macro_f1): 0.8324 Time: 4.38s
# test Loss: 0.5668 Main metric (macro_f1): 0.7265 Time: 0.50s
# ES Module Best: 0.5667804145812988, BadEpochs: 0
# Epoch 10/39
# ----------
# train Loss: 0.4620 Main metric (macro_f1): 0.8633 Time: 4.38s
# test Loss: 0.5625 Main metric (macro_f1): 0.6889 Time: 0.50s
# ES Module Best: 0.562482130130132, BadEpochs: 0
# Epoch 11/39
# ----------
# train Loss: 0.4428 Main metric (macro_f1): 0.8658 Time: 4.38s
# test Loss: 0.5491 Main metric (macro_f1): 0.7082 Time: 0.50s
# ES Module Best: 0.5491247872511545, BadEpochs: 0
# Epoch 12/39
# ----------
# train Loss: 0.3918 Main metric (macro_f1): 0.8882 Time: 4.39s
# test Loss: 0.5430 Main metric (macro_f1): 0.6986 Time: 0.50s
# ES Module Best: 0.5429919767379761, BadEpochs: 0
# Epoch 13/39
# ----------
# train Loss: 0.3618 Main metric (macro_f1): 0.9216 Time: 4.38s
# test Loss: 0.5275 Main metric (macro_f1): 0.7022 Time: 0.50s
# ES Module Best: 0.5274771014849345, BadEpochs: 0
# Epoch 14/39
# ----------
# train Loss: 0.3168 Main metric (macro_f1): 0.9536 Time: 4.39s
# test Loss: 0.5238 Main metric (macro_f1): 0.7491 Time: 0.50s
# ES Module Best: 0.5237834938367207, BadEpochs: 0
# Epoch 15/39
# ----------
# train Loss: 0.2891 Main metric (macro_f1): 0.9513 Time: 4.39s
# test Loss: 0.5129 Main metric (macro_f1): 0.7117 Time: 0.50s
# ES Module Best: 0.512941043774287, BadEpochs: 0
# Epoch 16/39
# ----------
# train Loss: 0.2672 Main metric (macro_f1): 0.9570 Time: 4.40s
# test Loss: 0.5082 Main metric (macro_f1): 0.7427 Time: 0.50s
# ES Module Best: 0.5081772541999817, BadEpochs: 0
# Epoch 17/39
# ----------
# train Loss: 0.2344 Main metric (macro_f1): 0.9641 Time: 4.39s
# test Loss: 0.5099 Main metric (macro_f1): 0.7335 Time: 0.50s
# ES Module Best: 0.5081772541999817, BadEpochs: 1
# Epoch 18/39
# ----------
# train Loss: 0.1947 Main metric (macro_f1): 0.9786 Time: 4.37s
# test Loss: 0.5185 Main metric (macro_f1): 0.7418 Time: 0.50s
# ES Module Best: 0.5081772541999817, BadEpochs: 2
# Epoch 19/39
# ----------
# train Loss: 0.2144 Main metric (macro_f1): 0.9590 Time: 4.37s
# test Loss: 0.5293 Main metric (macro_f1): 0.7548 Time: 0.50s
# ES Module Best: 0.5081772541999817, BadEpochs: 3
# Epoch 20/39
# ----------
# train Loss: 0.1625 Main metric (macro_f1): 0.9821 Time: 4.40s
# test Loss: 0.5208 Main metric (macro_f1): 0.7418 Time: 0.50s
# ES Module Best: 0.5081772541999817, BadEpochs: 4
# Epoch 21/39
# ----------
# train Loss: 0.1470 Main metric (macro_f1): 0.9839 Time: 4.38s
# test Loss: 0.5219 Main metric (macro_f1): 0.7329 Time: 0.50s
# ES Module Best: 0.5081772541999817, BadEpochs: 5
# Early stopping... Best Epoch: 16
# Training complete in 1m 52s
# Best test epoch loss: 0.508177
# Best test main metric: 0.754778
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.47429351131121317
# Micro Accuracy 0.7866666913032532
# Macro Accuracy 0.7290552854537964
# Macro Precision 0.7766084671020508
# Macro Recall 0.7290552854537964
# Macro F1 0.7427101135253906
#
# ------------------------- PER CLASS METRICS -------------------------
#                       class  precision    recall        f1
# 0  paragolpe_delantero_roto   0.756757  0.549020  0.636364
# 1  paragolpe_delantero_sano   0.796460  0.909091  0.849057
