# %% [markdown]
# ## Introducción
#
# Entrenamiento de modelo preentrenado para resolver el problema de predecir el ángulo del auto en base a la imagen.
#
# Fuertemente basado en:
# - https://towardsdatascience.com/a-practical-example-in-transfer-learning-with-pytorch-846bb835f2db
# - https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

# %% [markdown]
# ## Imports

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.datasets as datasets
import torchvision.models as models
import torchvision.transforms as transforms
from torchmetrics import MetricCollection, Accuracy, Precision, Recall, F1, ConfusionMatrix
import pandas as pd
import sklearn
from torch.utils.tensorboard import SummaryWriter

from datetime import datetime
import os

import importlib
import training_helper
from dataset_modules.one_part_dataset import OnePartDataset
import metrics_helper

importlib.reload(training_helper)
importlib.reload(metrics_helper)
# Out:
# <module 'metrics_helper' from '/clusteruy/home/franco.cuevas/metrics_helper.py'>

# %% [markdown]
# ## Variables

# %%
MODEL_NAME = "one_part_model"
EXPERIMENT_NAME = "resnet50_faroldelder_fine_tuning-final"
FEATURE_EXTRACTION = False
parte = "Farol Delantero Derecho"

device_string = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(device_string)

if device_string == "cuda":
    print("Usando GPU!")

os.makedirs("./trained_models/{}/{}/".format(MODEL_NAME, EXPERIMENT_NAME), exist_ok=True)
# Out:
# Usando GPU!

# %% [markdown]
# ## Dataset
#
# Se crea un dataset de tipo `ImageFolder` que se toma de la carpeta `dataset`, donde cada subcarpeta es una de las categorías a entrenar.
#
# Automáticamente mapea categorías a números `dataset.class_to_idx`.
#
# Finalmente se hace el split en train y test en 80/20.

# %%
print("start to load dataset")
dataset = OnePartDataset(
    parte,
    transform=transforms.Compose([
        transforms.ColorJitter(0.1, 0.1, 0.1, 0.1),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    root='/scratch/franco.cuevas/imgs/',
    preload=True
)
print("finish to load dataset")

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size], generator=torch.Generator().manual_seed(42))

classes = dataset.classes

dataset_sizes = {
    'train': len(train_dataset),
    'test': len(test_dataset)
}

print("#TRAIN {} #TEST {}".format(dataset_sizes["train"], dataset_sizes["test"]))
# Out:
# start to load dataset
# ----- CLASS DISTRIBUTION -----
# Class: no_farol_delantero_derecho, #1159, 69.61%
# Class: farol_delantero_derecho_sano, #376, 22.58%
# Class: farol_delantero_derecho_roto, #130, 7.81%
# finish to load dataset
# #TRAIN 1332 #TEST 333

# %% [markdown]
# ## Loaders
# Luego, se crean loaders para cada uno de los conjuntos. Los loaders permiten procesar los datos de a batches.

# %%
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True,
    num_workers=0
)

test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=16,
    shuffle=True,
    num_workers=0
)

dataloaders = {
    'train': train_loader,
    'test': test_loader
}

# %% [markdown]
# ## Entrenamiento
#
# En este step se carga el modelo pre-entrenado. Para este ejemplo se utiliza el modelo alexnet por su simplicidad.

# %% [markdown]
# #### ¿Finetuning o Feature extraction?
#
# - **Finetuning:** Consiste en incializar la red con los pesos pre-entrenados, y re-entrenar toda la red (ajustar los parámetros de todas las capas) con el dataset custom.
# - **Feature extraction:** La diferencia con lo anterior es que se congelan las capas convolucionales, de modo que el entrenamiento no las cambie con nuestros datos.
#
# En ambos casos pisamos la capa de **clasificador** por una capa nueva con 8 categorías, porque el modelo pre-entrenado tiene 1000 labels.

# %%
model = models.resnet50(pretrained=True)
NUM_CLASSES = len(classes)

if FEATURE_EXTRACTION:
    for param in model.parameters():
        param.requires_grad = False

model.fc = torch.nn.Linear(2048, NUM_CLASSES)
model = model.to(device)

# Tensorboard metrics writer
writer = SummaryWriter(log_dir='./trained_models/{}/tensorboard/{}'.format(MODEL_NAME, EXPERIMENT_NAME + '-' + datetime.now().strftime("%Y%m%d-%H%M%S")))

# Función de error
criterion = F.cross_entropy

# Optimizador
parameters_to_update = model.parameters()

if FEATURE_EXTRACTION:
    parameters_to_update = model.fc.parameters()

optimizer = optim.SGD(parameters_to_update, lr=0.001)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=3, bias=True)
# )

# %%
model = training_helper.train_model(
    model, 
    criterion, 
    optimizer, 
    dataloaders, 
    dataset_sizes, 
    device, 
    writer, 
    NUM_CLASSES,
    'trained_models/{}/{}'.format(MODEL_NAME, EXPERIMENT_NAME),
    main_metric='macro_f1', 
    num_epochs=30
)
# Out:
# Epoch 0/29
# ----------
# train Loss: 0.8118 Main metric (macro_f1): 0.3370 Time: 9.41s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8117635398655683
# Micro Accuracy 0.6734234094619751
# Macro Accuracy 0.3369806706905365
# Macro Precision 0.3224616050720215
# Macro Recall 0.3369806706905365
# Macro F1 0.3369806706905365
#
# test Loss: 0.6880 Main metric (macro_f1): 0.3333 Time: 1.00s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.687968270019726
# Micro Accuracy 0.717717707157135
# Macro Accuracy 0.3333333432674408
# Macro Precision 0.23923924565315247
# Macro Recall 0.3333333432674408
# Macro F1 0.3333333432674408
#
#
# Epoch 1/29
# ----------
# train Loss: 0.7355 Main metric (macro_f1): 0.3333 Time: 9.84s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7355173905869504
# Micro Accuracy 0.6906906962394714
# Macro Accuracy 0.3333333432674408
# Macro Precision 0.23040321469306946
# Macro Recall 0.3333333432674408
# Macro F1 0.3333333432674408
#
# test Loss: 0.6474 Main metric (macro_f1): 0.3333 Time: 1.06s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.647393113857991
# Micro Accuracy 0.717717707157135
# Macro Accuracy 0.3333333432674408
# Macro Precision 0.23923924565315247
# Macro Recall 0.3333333432674408
# Macro F1 0.3333333432674408
#
#
# Epoch 2/29
# ----------
# train Loss: 0.6709 Main metric (macro_f1): 0.3474 Time: 11.18s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.670940736034611
# Micro Accuracy 0.6996996998786926
# Macro Accuracy 0.3474154770374298
# Macro Precision 0.5036094188690186
# Macro Recall 0.3474154770374298
# Macro F1 0.3474154770374298
#
# test Loss: 0.5895 Main metric (macro_f1): 0.4300 Time: 1.07s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5894984627092207
# Micro Accuracy 0.7777777910232544
# Macro Accuracy 0.43002644181251526
# Macro Precision 0.5151815414428711
# Macro Recall 0.43002644181251526
# Macro F1 0.43002644181251526
#
#
# Epoch 3/29
# ----------
# train Loss: 0.6091 Main metric (macro_f1): 0.4015 Time: 13.29s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.6090643119525623
# Micro Accuracy 0.7357357144355774
# Macro Accuracy 0.40149760246276855
# Macro Precision 0.4997483789920807
# Macro Recall 0.40149760246276855
# Macro F1 0.40149760246276855
#
# test Loss: 0.5270 Main metric (macro_f1): 0.4432 Time: 1.14s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5269798983682741
# Micro Accuracy 0.7867867946624756
# Macro Accuracy 0.44318434596061707
# Macro Precision 0.5248485207557678
# Macro Recall 0.44318434596061707
# Macro F1 0.44318434596061707
#
#
# Epoch 4/29
# ----------
# train Loss: 0.5399 Main metric (macro_f1): 0.4774 Time: 14.04s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5399202997978028
# Micro Accuracy 0.7860360145568848
# Macro Accuracy 0.47743964195251465
# Macro Precision 0.5122352838516235
# Macro Recall 0.47743964195251465
# Macro F1 0.47743964195251465
#
# test Loss: 0.4674 Main metric (macro_f1): 0.5060 Time: 1.26s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4674039832106582
# Micro Accuracy 0.8318318128585815
# Macro Accuracy 0.505982518196106
# Macro Precision 0.5458186268806458
# Macro Recall 0.505982518196106
# Macro F1 0.505982518196106
#
#
# Epoch 5/29
# ----------
# train Loss: 0.4670 Main metric (macro_f1): 0.5489 Time: 15.01s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.46696776366448617
# Micro Accuracy 0.8348348140716553
# Macro Accuracy 0.5489130616188049
# Macro Precision 0.5409612655639648
# Macro Recall 0.5489130616188049
# Macro F1 0.5489130616188049
#
# test Loss: 0.4244 Main metric (macro_f1): 0.5953 Time: 1.19s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4244421370573588
# Micro Accuracy 0.8888888955116272
# Macro Accuracy 0.5952984094619751
# Macro Precision 0.565782904624939
# Macro Recall 0.5952984094619751
# Macro F1 0.5952984094619751
#
#
# Epoch 6/29
# ----------
# train Loss: 0.4051 Main metric (macro_f1): 0.5993 Time: 14.39s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.40508293693846054
# Micro Accuracy 0.8663663864135742
# Macro Accuracy 0.5993236899375916
# Macro Precision 0.5474022626876831
# Macro Recall 0.5993236899375916
# Macro F1 0.5993236899375916
#
# test Loss: 0.3720 Main metric (macro_f1): 0.5776 Time: 1.15s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3719628074684659
# Micro Accuracy 0.8828828930854797
# Macro Accuracy 0.5775526762008667
# Macro Precision 0.5683143138885498
# Macro Recall 0.5775526762008667
# Macro F1 0.5775526762008667
#
#
# Epoch 7/29
# ----------
# train Loss: 0.3595 Main metric (macro_f1): 0.6130 Time: 11.69s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3594919269507354
# Micro Accuracy 0.8761261105537415
# Macro Accuracy 0.6130193471908569
# Macro Precision 0.5558072328567505
# Macro Recall 0.6130193471908569
# Macro F1 0.6130193471908569
#
# test Loss: 0.3471 Main metric (macro_f1): 0.5995 Time: 1.06s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.34712822999324167
# Micro Accuracy 0.8978978991508484
# Macro Accuracy 0.5994824767112732
# Macro Precision 0.5739650726318359
# Macro Recall 0.5994824767112732
# Macro F1 0.5994824767112732
#
#
# Epoch 8/29
# ----------
# train Loss: 0.3223 Main metric (macro_f1): 0.6230 Time: 14.05s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.32230419367999286
# Micro Accuracy 0.8821321129798889
# Macro Accuracy 0.6230244636535645
# Macro Precision 0.8911312818527222
# Macro Recall 0.6230244636535645
# Macro F1 0.6230244636535645
#
# test Loss: 0.3202 Main metric (macro_f1): 0.6180 Time: 1.08s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.32017937338388003
# Micro Accuracy 0.9009009003639221
# Macro Accuracy 0.6180009841918945
# Macro Precision 0.9107730388641357
# Macro Recall 0.6180009841918945
# Macro F1 0.6180009841918945
#
#
# Epoch 9/29
# ----------
# train Loss: 0.2894 Main metric (macro_f1): 0.6393 Time: 13.19s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2893658862994598
# Micro Accuracy 0.8941441178321838
# Macro Accuracy 0.6393047571182251
# Macro Precision 0.8982434272766113
# Macro Recall 0.6393047571182251
# Macro F1 0.6393047571182251
#
# test Loss: 0.3186 Main metric (macro_f1): 0.6342 Time: 1.12s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.31861096003034095
# Micro Accuracy 0.9099099040031433
# Macro Accuracy 0.6341501474380493
# Macro Precision 0.9155641198158264
# Macro Recall 0.6341501474380493
# Macro F1 0.6341501474380493
#
#
# Epoch 10/29
# ----------
# train Loss: 0.2740 Main metric (macro_f1): 0.6542 Time: 12.27s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.27399008472760517
# Micro Accuracy 0.8978978991508484
# Macro Accuracy 0.6541856527328491
# Macro Precision 0.9031171202659607
# Macro Recall 0.6541856527328491
# Macro F1 0.6541856527328491
#
# test Loss: 0.2935 Main metric (macro_f1): 0.6429 Time: 1.12s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.29352673906105775
# Micro Accuracy 0.9159159064292908
# Macro Accuracy 0.6429221034049988
# Macro Precision 0.919678807258606
# Macro Recall 0.6429221034049988
# Macro F1 0.6429221034049988
#
#
# Epoch 11/29
# ----------
# train Loss: 0.2605 Main metric (macro_f1): 0.6705 Time: 12.98s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2604827031985418
# Micro Accuracy 0.9069069027900696
# Macro Accuracy 0.6705003976821899
# Macro Precision 0.9079960584640503
# Macro Recall 0.6705003976821899
# Macro F1 0.6705003976821899
#
# test Loss: 0.2845 Main metric (macro_f1): 0.6459 Time: 1.14s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2844667783728591
# Micro Accuracy 0.9159159064292908
# Macro Accuracy 0.6459133625030518
# Macro Precision 0.9184885025024414
# Macro Recall 0.6459133625030518
# Macro F1 0.6459133625030518
#
#
# Epoch 12/29
# ----------
# train Loss: 0.2298 Main metric (macro_f1): 0.6757 Time: 13.35s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.22979289731821856
# Micro Accuracy 0.9069069027900696
# Macro Accuracy 0.6757280826568604
# Macro Precision 0.9076286554336548
# Macro Recall 0.6757280826568604
# Macro F1 0.6757280826568604
#
# test Loss: 0.2818 Main metric (macro_f1): 0.6503 Time: 1.16s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2818105392627888
# Micro Accuracy 0.9189189076423645
# Macro Accuracy 0.6502993106842041
# Macro Precision 0.9187896251678467
# Macro Recall 0.6502993106842041
# Macro F1 0.6502993106842041
#
#
# Epoch 13/29
# ----------
# train Loss: 0.2141 Main metric (macro_f1): 0.6969 Time: 13.35s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.21409956126420707
# Micro Accuracy 0.912912905216217
# Macro Accuracy 0.6969237327575684
# Macro Precision 0.8925321102142334
# Macro Recall 0.6969237327575684
# Macro F1 0.6969237327575684
#
# test Loss: 0.2774 Main metric (macro_f1): 0.6415 Time: 1.14s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2773590379649096
# Micro Accuracy 0.912912905216217
# Macro Accuracy 0.6415274143218994
# Macro Precision 0.9164106249809265
# Macro Recall 0.6415274143218994
# Macro F1 0.6415274143218994
#
#
# Epoch 14/29
# ----------
# train Loss: 0.2137 Main metric (macro_f1): 0.7248 Time: 13.00s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2136608074019263
# Micro Accuracy 0.922672688961029
# Macro Accuracy 0.7247912883758545
# Macro Precision 0.9201121926307678
# Macro Recall 0.7247912883758545
# Macro F1 0.7247912883758545
#
# test Loss: 0.2698 Main metric (macro_f1): 0.6459 Time: 1.15s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2698222473934964
# Micro Accuracy 0.9159159064292908
# Macro Accuracy 0.6459133625030518
# Macro Precision 0.9184885025024414
# Macro Recall 0.6459133625030518
# Macro F1 0.6459133625030518
#
#
# Epoch 15/29
# ----------
# train Loss: 0.1918 Main metric (macro_f1): 0.7285 Time: 13.55s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.1918041468024612
# Micro Accuracy 0.9234234094619751
# Macro Accuracy 0.7285162210464478
# Macro Precision 0.9210207462310791
# Macro Recall 0.7285162210464478
# Macro F1 0.7285162210464478
#
# test Loss: 0.2759 Main metric (macro_f1): 0.6527 Time: 1.16s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2759424410424791
# Micro Accuracy 0.912912905216217
# Macro Accuracy 0.6526687145233154
# Macro Precision 0.9189077615737915
# Macro Recall 0.6526687145233154
# Macro F1 0.6526687145233154
#
#
# Epoch 16/29
# ----------
# train Loss: 0.1832 Main metric (macro_f1): 0.7516 Time: 12.25s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.1832328453973249
# Micro Accuracy 0.9301801919937134
# Macro Accuracy 0.751571774482727
# Macro Precision 0.9252814054489136
# Macro Recall 0.751571774482727
# Macro F1 0.751571774482727
#
# test Loss: 0.2665 Main metric (macro_f1): 0.6702 Time: 1.71s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.26648552013231114
# Micro Accuracy 0.924924910068512
# Macro Accuracy 0.6702125668525696
# Macro Precision 0.9269809722900391
# Macro Recall 0.6702125668525696
# Macro F1 0.6702125668525696
#
#
# Epoch 17/29
# ----------
# train Loss: 0.1652 Main metric (macro_f1): 0.7619 Time: 14.54s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.16523296200298332
# Micro Accuracy 0.9369369149208069
# Macro Accuracy 0.761939287185669
# Macro Precision 0.9291996955871582
# Macro Recall 0.761939287185669
# Macro F1 0.761939287185669
#
# test Loss: 0.2721 Main metric (macro_f1): 0.6765 Time: 1.16s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2721238332065018
# Micro Accuracy 0.9099099040031433
# Macro Accuracy 0.6765478849411011
# Macro Precision 0.7166057229042053
# Macro Recall 0.6765478849411011
# Macro F1 0.6765478849411011
#
#
# Epoch 18/29
# ----------
# train Loss: 0.1692 Main metric (macro_f1): 0.8111 Time: 13.19s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.16915911480829166
# Micro Accuracy 0.9444444179534912
# Macro Accuracy 0.8111007809638977
# Macro Precision 0.9394774436950684
# Macro Recall 0.8111007809638977
# Macro F1 0.8111007809638977
#
# test Loss: 0.2646 Main metric (macro_f1): 0.6742 Time: 1.19s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2646051536540727
# Micro Accuracy 0.9159159064292908
# Macro Accuracy 0.6741784811019897
# Macro Precision 0.7580548524856567
# Macro Recall 0.6741784811019897
# Macro F1 0.6741784811019897
#
#
# Epoch 19/29
# ----------
# train Loss: 0.1456 Main metric (macro_f1): 0.8497 Time: 14.41s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.145555833774107
# Micro Accuracy 0.9602102041244507
# Macro Accuracy 0.8497222661972046
# Macro Precision 0.947314441204071
# Macro Recall 0.8497222661972046
# Macro F1 0.8497222661972046
#
# test Loss: 0.2615 Main metric (macro_f1): 0.6772 Time: 1.12s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.26151313124834236
# Micro Accuracy 0.9159159064292908
# Macro Accuracy 0.6771697998046875
# Macro Precision 0.7548990845680237
# Macro Recall 0.6771697998046875
# Macro F1 0.6771697998046875
#
#
# Epoch 20/29
# ----------
# train Loss: 0.1311 Main metric (macro_f1): 0.8359 Time: 12.46s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.13112783194841207
# Micro Accuracy 0.9579579830169678
# Macro Accuracy 0.8359472751617432
# Macro Precision 0.9488681554794312
# Macro Recall 0.8359472751617432
# Macro F1 0.8359472751617432
#
# test Loss: 0.2649 Main metric (macro_f1): 0.6995 Time: 1.22s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2648558962989498
# Micro Accuracy 0.9159159064292908
# Macro Accuracy 0.6994523406028748
# Macro Precision 0.7652150392532349
# Macro Recall 0.6994523406028748
# Macro F1 0.6994523406028748
#
#
# Epoch 21/29
# ----------
# train Loss: 0.1292 Main metric (macro_f1): 0.8702 Time: 13.51s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.12918486891387104
# Micro Accuracy 0.9639639854431152
# Macro Accuracy 0.8701984286308289
# Macro Precision 0.9576140642166138
# Macro Recall 0.8701984286308289
# Macro F1 0.8701984286308289
#
# test Loss: 0.2645 Main metric (macro_f1): 0.7024 Time: 1.21s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.26449361899951557
# Micro Accuracy 0.9159159064292908
# Macro Accuracy 0.7024435997009277
# Macro Precision 0.7612594366073608
# Macro Recall 0.7024435997009277
# Macro F1 0.7024435997009277
#
#
# Epoch 22/29
# ----------
# train Loss: 0.1195 Main metric (macro_f1): 0.8694 Time: 13.07s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.11952191204190613
# Micro Accuracy 0.9654654860496521
# Macro Accuracy 0.8694393038749695
# Macro Precision 0.9589045643806458
# Macro Recall 0.8694393038749695
# Macro F1 0.8694393038749695
#
# test Loss: 0.2610 Main metric (macro_f1): 0.7170 Time: 1.12s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2609606972327819
# Micro Accuracy 0.9279279112815857
# Macro Accuracy 0.7169961929321289
# Macro Precision 0.7709362506866455
# Macro Recall 0.7169961929321289
# Macro F1 0.7169961929321289
#
#
# Epoch 23/29
# ----------
# train Loss: 0.1153 Main metric (macro_f1): 0.8865 Time: 12.39s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.11526298072110783
# Micro Accuracy 0.9699699878692627
# Macro Accuracy 0.8865476846694946
# Macro Precision 0.9658347964286804
# Macro Recall 0.8865476846694946
# Macro F1 0.8865476846694946
#
# test Loss: 0.2609 Main metric (macro_f1): 0.7068 Time: 1.14s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2608967580952802
# Micro Accuracy 0.9189189076423645
# Macro Accuracy 0.7068295478820801
# Macro Precision 0.7495079040527344
# Macro Recall 0.7068295478820801
# Macro F1 0.7068295478820801
#
#
# Epoch 24/29
# ----------
# train Loss: 0.0998 Main metric (macro_f1): 0.9215 Time: 14.57s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.09981974970560532
# Micro Accuracy 0.9797297120094299
# Macro Accuracy 0.9215079545974731
# Macro Precision 0.9729714393615723
# Macro Recall 0.9215079545974731
# Macro F1 0.9215079545974731
#
# test Loss: 0.2590 Main metric (macro_f1): 0.7082 Time: 1.10s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.25896816998272687
# Micro Accuracy 0.9219219088554382
# Macro Accuracy 0.7082242965698242
# Macro Precision 0.7668934464454651
# Macro Recall 0.7082242965698242
# Macro F1 0.7082242965698242
#
#
# Epoch 25/29
# ----------
# train Loss: 0.0944 Main metric (macro_f1): 0.9423 Time: 12.32s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.09444549066705389
# Micro Accuracy 0.9849849939346313
# Macro Accuracy 0.9423413276672363
# Macro Precision 0.9797219634056091
# Macro Recall 0.9423413276672363
# Macro F1 0.9423413276672363
#
# test Loss: 0.2644 Main metric (macro_f1): 0.6833 Time: 1.18s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.26436165234706066
# Micro Accuracy 0.9069069027900696
# Macro Accuracy 0.68330317735672
# Macro Precision 0.7359103560447693
# Macro Recall 0.68330317735672
# Macro F1 0.68330317735672
#
#
# Epoch 26/29
# ----------
# train Loss: 0.0936 Main metric (macro_f1): 0.9483 Time: 13.99s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.09356460825459019
# Micro Accuracy 0.9864864945411682
# Macro Accuracy 0.9482936859130859
# Macro Precision 0.9823457598686218
# Macro Recall 0.9482936859130859
# Macro F1 0.9482936859130859
#
# test Loss: 0.2638 Main metric (macro_f1): 0.6805 Time: 1.18s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.263797594844042
# Micro Accuracy 0.9009009003639221
# Macro Accuracy 0.6805137991905212
# Macro Precision 0.6859363317489624
# Macro Recall 0.6805137991905212
# Macro F1 0.6805137991905212
#
#
# Epoch 27/29
# ----------
# train Loss: 0.0839 Main metric (macro_f1): 0.9509 Time: 13.01s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.08387116132466285
# Micro Accuracy 0.9857357144355774
# Macro Accuracy 0.9509127140045166
# Macro Precision 0.9838164448738098
# Macro Recall 0.9509127140045166
# Macro F1 0.9509127140045166
#
# test Loss: 0.2615 Main metric (macro_f1): 0.6946 Time: 1.17s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.26145577215933585
# Micro Accuracy 0.9009009003639221
# Macro Accuracy 0.6946463584899902
# Macro Precision 0.7136207818984985
# Macro Recall 0.6946463584899902
# Macro F1 0.6946463584899902
#
#
# Epoch 28/29
# ----------
# train Loss: 0.0719 Main metric (macro_f1): 0.9740 Time: 14.44s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.07193058571434235
# Micro Accuracy 0.9924924969673157
# Macro Accuracy 0.9739683270454407
# Macro Precision 0.9849961400032043
# Macro Recall 0.9739683270454407
# Macro F1 0.9739683270454407
#
# test Loss: 0.2576 Main metric (macro_f1): 0.7064 Time: 1.13s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2575879994186911
# Micro Accuracy 0.9069069027900696
# Macro Accuracy 0.7064095139503479
# Macro Precision 0.7161133289337158
# Macro Recall 0.7064095139503479
# Macro F1 0.7064095139503479
#
#
# Epoch 29/29
# ----------
# train Loss: 0.0672 Main metric (macro_f1): 0.9721 Time: 12.67s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.06715358666203043
# Micro Accuracy 0.9924924969673157
# Macro Accuracy 0.9721032381057739
# Macro Precision 0.9898978471755981
# Macro Recall 0.9721032381057739
# Macro F1 0.9721032381057739
#
# test Loss: 0.2630 Main metric (macro_f1): 0.6849 Time: 1.16s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.26301494540573955
# Micro Accuracy 0.9039039015769958
# Macro Accuracy 0.6848997473716736
# Macro Precision 0.6941015720367432
# Macro Recall 0.6848997473716736
# Macro F1 0.6848997473716736
#
#
# Training complete in 7m 14s
# Best test main metric: 0.716996

# %%
BEST_MODEL_PATH = './trained_models/{}/{}/best_model.pth'.format(MODEL_NAME, EXPERIMENT_NAME)
os.makedirs(os.path.dirname(BEST_MODEL_PATH), exist_ok=True)
torch.save(model.state_dict(), BEST_MODEL_PATH)

# %% [markdown]
# ## Evaluación final

# %%
from dataset_modules.common import pil_loader
model.load_state_dict(torch.load(BEST_MODEL_PATH))
model.eval()

metrics = metrics_helper.init_metrics(device, NUM_CLASSES)
tensorboard_transforms = transforms.Compose([
    transforms.ToTensor()
])

total_loss = 0.0

for i, (images, labels, imgs_path) in enumerate(test_loader):
    images = images.to(device)
    labels = labels.to(device)
    
    with torch.no_grad():
        outputs = model(images)
        metrics(outputs, labels)
        
        predictions = torch.argmax(outputs, dim=1)
        loss = criterion(outputs, labels)
        
        total_loss += loss.item() * images.size(0)
        
        for sampleno in range(images.shape[0]):
            if(labels[sampleno] != predictions[sampleno]):
                name = 'Misclasified_Predicted-{}_Classified-{}/{}'.format(classes[predictions[sampleno]], classes[labels[sampleno]], imgs_path[sampleno])
                
                writer.add_image(name, tensorboard_transforms(pil_loader('/scratch/franco.cuevas/imgs/' + imgs_path[sampleno])))
                writer.flush()
        
total_loss /= dataset_sizes["test"]

metrics_result = metrics.compute()

# %%
macro_metrics = metrics_helper.generate_macro_metrics(metrics_result, total_loss)
per_class_metrics = metrics_helper.generate_per_class_metrics(metrics_result, classes)

macro_metrics.to_csv('./trained_models/{}/{}/best_model_macro_metrics.csv'.format(MODEL_NAME, EXPERIMENT_NAME), index=False)
per_class_metrics.to_csv('./trained_models/{}/{}/best_model_per_class_metrics.csv'.format(MODEL_NAME, EXPERIMENT_NAME), index=False)
# Out:
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.26096070866595517
# Micro Accuracy 0.9279279112815857
# Macro Accuracy 0.7169961929321289
# Macro Precision 0.7709362506866455
# Macro Recall 0.7169961929321289
# Macro F1 0.7169961929321289
#
# ------------------------- PER CLASS METRICS -------------------------
#                           class  accuracy  precision    recall        f1
# 0  farol_delantero_derecho_roto  0.277778   0.500000  0.277778  0.277778
# 1  farol_delantero_derecho_sano  0.881579   0.837500  0.881579  0.881579
# 2    no_farol_delantero_derecho  0.991632   0.975309  0.991632  0.991632

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

df_cm = pd.DataFrame(metrics_result['confusion_matrix'], index = classes,
                  columns = classes)

df_cm = df_cm.applymap(lambda x: x.item())

plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap="Blues")
df_cm.to_csv('./trained_models/{}/{}/confusion_matrix.csv'.format(MODEL_NAME, EXPERIMENT_NAME))
