# %% [markdown]
# ## Introducción
#
# Entrenamiento de modelo preentrenado para resolver el problema de predecir el ángulo del auto en base a la imagen.
#
# Fuertemente basado en:
# - https://towardsdatascience.com/a-practical-example-in-transfer-learning-with-pytorch-846bb835f2db
# - https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

# %% [markdown]
# ## Imports

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.datasets as datasets
import torchvision.models as models
import torchvision.transforms as transforms
from torchmetrics import MetricCollection, Accuracy, Precision, Recall, F1, ConfusionMatrix
import pandas as pd
import sklearn
from torch.utils.tensorboard import SummaryWriter

from datetime import datetime
import os

import importlib
import training_helper
from dataset_modules.one_part_dataset import OnePartDataset
import metrics_helper

importlib.reload(training_helper)
importlib.reload(metrics_helper)
# Out:
# <module 'metrics_helper' from '/Users/fcuevas/Documents/fing/tesis/jupyters/metrics_helper.py'>

# %% [markdown]
# ## Variables

# %%
MODEL_NAME = "one_part_model"
EXPERIMENT_NAME = "alexnet_paragolpe_feature_extraction"
FEATURE_EXTRACTION = True

device_string = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(device_string)

if device_string == "cuda":
    print("Usando GPU!")

# %%
os.makedirs(os.path.dirname("./trained_models/{}/{}/asd.txt".format(MODEL_NAME, EXPERIMENT_NAME)), exist_ok=True)

# %% [markdown]
# ## Dataset
#
# Se crea un dataset de tipo `ImageFolder` que se toma de la carpeta `dataset`, donde cada subcarpeta es una de las categorías a entrenar.
#
# Automáticamente mapea categorías a números `dataset.class_to_idx`.
#
# Finalmente se hace el split en train y test en 80/20.

# %%
dataset = OnePartDataset(
    "Paragolpe Delantero",
    transform=transforms.Compose([
        transforms.ColorJitter(0.1, 0.1, 0.1, 0.1),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
)

train_dataset, test_dataset = torch.utils.data.random_split(dataset, [len(dataset) - 100, 100])
classes = dataset.classes
dataset_sizes = {
    'train': len(train_dataset),
    'test': len(test_dataset)
}
# Out:
# ----- CLASS DISTRIBUTION -----
# Class: no_paragolpe_delantero, #266, 53.09%
# Class: paragolpe_delantero_roto, #126, 25.15%
# Class: paragolpe_delantero_sano, #109, 21.76%

# %% [markdown]
# ## Loaders
# Luego, se crean loaders para cada uno de los conjuntos. Los loaders permiten procesar los datos de a batches.

# %%
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True,
    num_workers=4
)

test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=16,
    shuffle=True,
    num_workers=4
)

dataloaders = {
    'train': train_loader,
    'test': test_loader
}

# %% [markdown]
# ## Entrenamiento
#
# En este step se carga el modelo pre-entrenado. Para este ejemplo se utiliza el modelo alexnet por su simplicidad.

# %% [markdown]
# #### ¿Finetuning o Feature extraction?
#
# - **Finetuning:** Consiste en incializar la red con los pesos pre-entrenados, y re-entrenar toda la red (ajustar los parámetros de todas las capas) con el dataset custom.
# - **Feature extraction:** La diferencia con lo anterior es que se congelan las capas convolucionales, de modo que el entrenamiento no las cambie con nuestros datos.
#
# En ambos casos pisamos la capa de **clasificador** por una capa nueva con 8 categorías, porque el modelo pre-entrenado tiene 1000 labels.

# %%
model = models.alexnet(pretrained=True)

NUM_CLASSES = len(classes)

if FEATURE_EXTRACTION:
    for param in model.parameters():
        param.requires_grad = False

model.classifier[6] = torch.nn.Linear(model.classifier[6].in_features, NUM_CLASSES)
model = model.to(device)

# Tensorboard metrics writer
writer = SummaryWriter(log_dir='./trained_models/{}/tensorboard/{}'.format(MODEL_NAME, EXPERIMENT_NAME + '-' + datetime.now().strftime("%Y%m%d-%H%M%S")))

# Función de error
criterion = F.cross_entropy

# Optimizador
parameters_to_update = model.parameters()

if FEATURE_EXTRACTION:
    parameters_to_update = model.classifier[6].parameters()

optimizer = optim.SGD(parameters_to_update, lr=0.001, momentum=0.9)
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=3, bias=True)
#   )
# )

# %%
model = training_helper.train_model(
    model, 
    criterion, 
    optimizer, 
    dataloaders, 
    dataset_sizes, 
    device, 
    writer, 
    NUM_CLASSES,
    'trained_models/{}/{}'.format(MODEL_NAME, EXPERIMENT_NAME),
    main_metric='macro_f1', 
    num_epochs=25
)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.9142 Main metric (macro_f1): 0.5019 Time: 55.32s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.9141817986454229
# Micro Accuracy 0.5960099697113037
# Macro Accuracy 0.5018677711486816
# Macro Precision 0.5049108266830444
# Macro Recall 0.5018677711486816
# Macro F1 0.5018677711486816
#
# test Loss: 0.7994 Main metric (macro_f1): 0.5695 Time: 33.45s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7993871760368347
# Micro Accuracy 0.6499999761581421
# Macro Accuracy 0.5695257186889648
# Macro Precision 0.5522187948226929
# Macro Recall 0.5695257186889648
# Macro F1 0.5695257186889648
#
#
# Epoch 1/24
# ----------
# train Loss: 0.6982 Main metric (macro_f1): 0.6664 Time: 49.32s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.6982419197157286
# Micro Accuracy 0.7331671118736267
# Macro Accuracy 0.6664189100265503
# Macro Precision 0.6675775051116943
# Macro Recall 0.6664189100265503
# Macro F1 0.6664189100265503
#
# test Loss: 1.0048 Main metric (macro_f1): 0.6173 Time: 32.40s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 1.0048142671585083
# Micro Accuracy 0.7599999904632568
# Macro Accuracy 0.6172839403152466
# Macro Precision 0.4913485050201416
# Macro Recall 0.6172839403152466
# Macro F1 0.6172839403152466
#
#
# Epoch 2/24
# ----------
# train Loss: 0.8835 Main metric (macro_f1): 0.6790 Time: 49.05s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8834759261542722
# Micro Accuracy 0.7306733131408691
# Macro Accuracy 0.6789785027503967
# Macro Precision 0.6809847354888916
# Macro Recall 0.6789785027503967
# Macro F1 0.6789785027503967
#
# test Loss: 1.0788 Main metric (macro_f1): 0.6173 Time: 32.00s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 1.0787869024276733
# Micro Accuracy 0.7599999904632568
# Macro Accuracy 0.6172839403152466
# Macro Precision 0.4930555820465088
# Macro Recall 0.6172839403152466
# Macro F1 0.6172839403152466
#
#
# Epoch 3/24
# ----------
# train Loss: 1.4773 Main metric (macro_f1): 0.5892 Time: 49.91s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 1.4773427577351583
# Micro Accuracy 0.6783042550086975
# Macro Accuracy 0.5892001986503601
# Macro Precision 0.6118854284286499
# Macro Recall 0.5892001986503601
# Macro F1 0.5892001986503601
#
# test Loss: 0.8977 Main metric (macro_f1): 0.6248 Time: 36.03s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8976987314224243
# Micro Accuracy 0.7200000286102295
# Macro Accuracy 0.6247563362121582
# Macro Precision 0.6217186450958252
# Macro Recall 0.6247563362121582
# Macro F1 0.6247563362121582
#
#
# Epoch 4/24
# ----------
# train Loss: 0.7591 Main metric (macro_f1): 0.7146 Time: 50.09s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7590672816347303
# Micro Accuracy 0.7730673551559448
# Macro Accuracy 0.7145702838897705
# Macro Precision 0.711794376373291
# Macro Recall 0.7145702838897705
# Macro F1 0.7145702838897705
#
# test Loss: 0.8304 Main metric (macro_f1): 0.5601 Time: 31.83s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8303669881820679
# Micro Accuracy 0.6600000262260437
# Macro Accuracy 0.5601039528846741
# Macro Precision 0.5592864751815796
# Macro Recall 0.5601039528846741
# Macro F1 0.5601039528846741
#
#
# Epoch 5/24
# ----------
# train Loss: 0.5320 Main metric (macro_f1): 0.7854 Time: 47.79s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5320162002108713
# Micro Accuracy 0.8254364132881165
# Macro Accuracy 0.7853916883468628
# Macro Precision 0.7877450585365295
# Macro Recall 0.7853916883468628
# Macro F1 0.7853916883468628
#
# test Loss: 0.8264 Main metric (macro_f1): 0.5854 Time: 31.57s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8264458894729614
# Micro Accuracy 0.7099999785423279
# Macro Accuracy 0.5854451060295105
# Macro Precision 0.542222261428833
# Macro Recall 0.5854451060295105
# Macro F1 0.5854451060295105
#
#
# Epoch 6/24
# ----------
# train Loss: 0.4241 Main metric (macro_f1): 0.7991 Time: 49.58s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4240553429461991
# Micro Accuracy 0.8453865051269531
# Macro Accuracy 0.7990915775299072
# Macro Precision 0.8010090589523315
# Macro Recall 0.7990915775299072
# Macro F1 0.7990915775299072
#
# test Loss: 1.0610 Main metric (macro_f1): 0.6491 Time: 31.80s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 1.0609987354278565
# Micro Accuracy 0.6899999976158142
# Macro Accuracy 0.6491228342056274
# Macro Precision 0.6230303049087524
# Macro Recall 0.6491228342056274
# Macro F1 0.6491228342056274
#
#
# Epoch 7/24
# ----------
# train Loss: 0.5095 Main metric (macro_f1): 0.7647 Time: 50.06s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5095069952439192
# Micro Accuracy 0.8154613375663757
# Macro Accuracy 0.7647449970245361
# Macro Precision 0.7654871344566345
# Macro Recall 0.7647449970245361
# Macro F1 0.7647449970245361
#
# test Loss: 0.8940 Main metric (macro_f1): 0.6287 Time: 33.95s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8939519383013248
# Micro Accuracy 0.75
# Macro Accuracy 0.628654956817627
# Macro Precision 0.661928653717041
# Macro Recall 0.628654956817627
# Macro F1 0.628654956817627
#
#
# Epoch 8/24
# ----------
# train Loss: 0.4855 Main metric (macro_f1): 0.7895 Time: 48.94s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.48548435278589885
# Micro Accuracy 0.8354114890098572
# Macro Accuracy 0.7895495891571045
# Macro Precision 0.796850323677063
# Macro Recall 0.7895495891571045
# Macro F1 0.7895495891571045
#
# test Loss: 0.7411 Main metric (macro_f1): 0.6199 Time: 36.07s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7410600686189719
# Micro Accuracy 0.7099999785423279
# Macro Accuracy 0.6198830604553223
# Macro Precision 0.6132664680480957
# Macro Recall 0.6198830604553223
# Macro F1 0.6198830604553223
#
#
# Epoch 9/24
# ----------
# train Loss: 0.3299 Main metric (macro_f1): 0.8203 Time: 55.01s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.329901772024031
# Micro Accuracy 0.8553615808486938
# Macro Accuracy 0.8203005194664001
# Macro Precision 0.8270905017852783
# Macro Recall 0.8203005194664001
# Macro F1 0.8203005194664001
#
# test Loss: 0.6744 Main metric (macro_f1): 0.6741 Time: 33.59s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.6744252061843872
# Micro Accuracy 0.7799999713897705
# Macro Accuracy 0.6741390824317932
# Macro Precision 0.6979798078536987
# Macro Recall 0.6741390824317932
# Macro F1 0.6741390824317932
#
#
# Epoch 10/24
# ----------
# train Loss: 0.3460 Main metric (macro_f1): 0.8278 Time: 80.71s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.34595273583755826
# Micro Accuracy 0.8678303956985474
# Macro Accuracy 0.8278255462646484
# Macro Precision 0.82924884557724
# Macro Recall 0.8278255462646484
# Macro F1 0.8278255462646484
#
# test Loss: 0.6492 Main metric (macro_f1): 0.6712 Time: 34.01s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.6491707777976989
# Micro Accuracy 0.7699999809265137
# Macro Accuracy 0.6712150573730469
# Macro Precision 0.6941380500793457
# Macro Recall 0.6712150573730469
# Macro F1 0.6712150573730469
#
#
# Epoch 11/24
# ----------
# train Loss: 0.3192 Main metric (macro_f1): 0.8560 Time: 51.43s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.31922516109191923
# Micro Accuracy 0.8802992701530457
# Macro Accuracy 0.8559907078742981
# Macro Precision 0.8586181402206421
# Macro Recall 0.8559907078742981
# Macro F1 0.8559907078742981
#
# test Loss: 0.7551 Main metric (macro_f1): 0.6517 Time: 31.49s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7551420760154725
# Micro Accuracy 0.699999988079071
# Macro Accuracy 0.6517219543457031
# Macro Precision 0.645622968673706
# Macro Recall 0.6517219543457031
# Macro F1 0.6517219543457031
#
#
# Epoch 12/24
# ----------
# train Loss: 0.3779 Main metric (macro_f1): 0.8339 Time: 48.40s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3778632376853962
# Micro Accuracy 0.8628429174423218
# Macro Accuracy 0.8338797092437744
# Macro Precision 0.8296784162521362
# Macro Recall 0.8338797092437744
# Macro F1 0.8338797092437744
#
# test Loss: 1.0917 Main metric (macro_f1): 0.6462 Time: 33.10s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 1.0917133617401122
# Micro Accuracy 0.7599999904632568
# Macro Accuracy 0.6461988091468811
# Macro Precision 0.7236430644989014
# Macro Recall 0.6461988091468811
# Macro F1 0.6461988091468811
#
#
# Epoch 13/24
# ----------
# train Loss: 0.3200 Main metric (macro_f1): 0.8219 Time: 49.16s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.31996753432804215
# Micro Accuracy 0.8628429174423218
# Macro Accuracy 0.8218759894371033
# Macro Precision 0.8288664221763611
# Macro Recall 0.8218759894371033
# Macro F1 0.8218759894371033
#
# test Loss: 0.6205 Main metric (macro_f1): 0.7495 Time: 32.96s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.6204949975013733
# Micro Accuracy 0.8100000023841858
# Macro Accuracy 0.7495126724243164
# Macro Precision 0.7581700086593628
# Macro Recall 0.7495126724243164
# Macro F1 0.7495126724243164
#
#
# Epoch 14/24
# ----------
# train Loss: 0.5187 Main metric (macro_f1): 0.7919 Time: 52.18s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5186871581541038
# Micro Accuracy 0.83790522813797
# Macro Accuracy 0.7919065356254578
# Macro Precision 0.8001863956451416
# Macro Recall 0.7919065356254578
# Macro F1 0.7919065356254578
#
# test Loss: 0.9720 Main metric (macro_f1): 0.6085 Time: 31.44s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.9719798135757446
# Micro Accuracy 0.699999988079071
# Macro Accuracy 0.6085120439529419
# Macro Precision 0.6092873215675354
# Macro Recall 0.6085120439529419
# Macro F1 0.6085120439529419
#
#
# Epoch 15/24
# ----------
# train Loss: 0.3605 Main metric (macro_f1): 0.8465 Time: 47.52s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3605056773360814
# Micro Accuracy 0.8753117322921753
# Macro Accuracy 0.846451997756958
# Macro Precision 0.845093309879303
# Macro Recall 0.846451997756958
# Macro F1 0.846451997756958
#
# test Loss: 0.6337 Main metric (macro_f1): 0.6683 Time: 31.24s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.6336799192428589
# Micro Accuracy 0.75
# Macro Accuracy 0.6682910919189453
# Macro Precision 0.66548091173172
# Macro Recall 0.6682910919189453
# Macro F1 0.6682910919189453
#
#
# Epoch 16/24
# ----------
# train Loss: 0.3417 Main metric (macro_f1): 0.8234 Time: 55.64s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3416596672026222
# Micro Accuracy 0.8603491187095642
# Macro Accuracy 0.823445200920105
# Macro Precision 0.8271371722221375
# Macro Recall 0.823445200920105
# Macro F1 0.823445200920105
#
# test Loss: 0.9661 Main metric (macro_f1): 0.6082 Time: 39.44s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.9660546455811709
# Micro Accuracy 0.7300000190734863
# Macro Accuracy 0.6081871390342712
# Macro Precision 0.6462706923484802
# Macro Recall 0.6081871390342712
# Macro F1 0.6081871390342712
#
#
# Epoch 17/24
# ----------
# train Loss: 0.2478 Main metric (macro_f1): 0.8725 Time: 49.66s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.24775276078968575
# Micro Accuracy 0.9002493619918823
# Macro Accuracy 0.8724954128265381
# Macro Precision 0.8750991821289062
# Macro Recall 0.8724954128265381
# Macro F1 0.8724954128265381
#
# test Loss: 0.6721 Main metric (macro_f1): 0.6592 Time: 33.12s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.6720590353012085
# Micro Accuracy 0.7300000190734863
# Macro Accuracy 0.65919429063797
# Macro Precision 0.660052478313446
# Macro Recall 0.65919429063797
# Macro F1 0.65919429063797
#
#
# Epoch 18/24
# ----------
# train Loss: 0.3054 Main metric (macro_f1): 0.8465 Time: 48.66s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.3054314921030884
# Micro Accuracy 0.8753117322921753
# Macro Accuracy 0.846451997756958
# Macro Precision 0.8438706398010254
# Macro Recall 0.846451997756958
# Macro F1 0.846451997756958
#
# test Loss: 0.7766 Main metric (macro_f1): 0.6452 Time: 31.33s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7766200868785381
# Micro Accuracy 0.7599999904632568
# Macro Accuracy 0.6452242136001587
# Macro Precision 0.6697192192077637
# Macro Recall 0.6452242136001587
# Macro F1 0.6452242136001587
#
#
# Epoch 19/24
# ----------
# train Loss: 0.3148 Main metric (macro_f1): 0.8677 Time: 49.03s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.31481621004269456
# Micro Accuracy 0.895261824131012
# Macro Accuracy 0.8676672577857971
# Macro Precision 0.8706982135772705
# Macro Recall 0.8676672577857971
# Macro F1 0.8676672577857971
#
# test Loss: 0.7018 Main metric (macro_f1): 0.6569 Time: 34.27s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.701799533367157
# Micro Accuracy 0.7400000095367432
# Macro Accuracy 0.6569200754165649
# Macro Precision 0.6592477560043335
# Macro Recall 0.6569200754165649
# Macro F1 0.6569200754165649
#
#
# Epoch 20/24
# ----------
# train Loss: 0.1780 Main metric (macro_f1): 0.9012 Time: 49.07s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.17803630634139006
# Micro Accuracy 0.9201995134353638
# Macro Accuracy 0.9012261629104614
# Macro Precision 0.8983441591262817
# Macro Recall 0.9012261629104614
# Macro F1 0.9012261629104614
#
# test Loss: 0.8409 Main metric (macro_f1): 0.6540 Time: 34.80s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8409304451942444
# Micro Accuracy 0.7200000286102295
# Macro Accuracy 0.6539961099624634
# Macro Precision 0.6427866220474243
# Macro Recall 0.6539961099624634
# Macro F1 0.6539961099624634
#
#
# Epoch 21/24
# ----------
# train Loss: 0.6187 Main metric (macro_f1): 0.7604 Time: 51.10s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.6187412548540369
# Micro Accuracy 0.8079800605773926
# Macro Accuracy 0.7603646516799927
# Macro Precision 0.7587268352508545
# Macro Recall 0.7603646516799927
# Macro F1 0.7603646516799927
#
# test Loss: 1.1588 Main metric (macro_f1): 0.6153 Time: 34.44s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 1.1588465785980224
# Micro Accuracy 0.7200000286102295
# Macro Accuracy 0.6153346300125122
# Macro Precision 0.622990608215332
# Macro Recall 0.6153346300125122
# Macro F1 0.6153346300125122
#
#
# Epoch 22/24
# ----------
# train Loss: 0.5984 Main metric (macro_f1): 0.7852 Time: 47.95s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.5983653374034357
# Micro Accuracy 0.8279301524162292
# Macro Accuracy 0.7851693630218506
# Macro Precision 0.784113883972168
# Macro Recall 0.7851693630218506
# Macro F1 0.7851693630218506
#
# test Loss: 0.8751 Main metric (macro_f1): 0.6056 Time: 31.06s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.8751410147175193
# Micro Accuracy 0.6800000071525574
# Macro Accuracy 0.6055880784988403
# Macro Precision 0.5935872793197632
# Macro Recall 0.6055880784988403
# Macro F1 0.6055880784988403
#
#
# Epoch 23/24
# ----------
# train Loss: 0.4412 Main metric (macro_f1): 0.8458 Time: 47.45s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.4412107293278053
# Micro Accuracy 0.8753117322921753
# Macro Accuracy 0.8457785844802856
# Macro Precision 0.8393125534057617
# Macro Recall 0.8457785844802856
# Macro F1 0.8457785844802856
#
# test Loss: 0.9340 Main metric (macro_f1): 0.5942 Time: 31.64s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.934049916267395
# Micro Accuracy 0.6800000071525574
# Macro Accuracy 0.59421706199646
# Macro Precision 0.5847848653793335
# Macro Recall 0.59421706199646
# Macro F1 0.59421706199646
#
#
# Epoch 24/24
# ----------
# train Loss: 0.2853 Main metric (macro_f1): 0.8687 Time: 51.03s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.2852689056771057
# Micro Accuracy 0.8902742862701416
# Macro Accuracy 0.8686741590499878
# Macro Precision 0.8618146181106567
# Macro Recall 0.8686741590499878
# Macro F1 0.8686741590499878
#
# test Loss: 0.7517 Main metric (macro_f1): 0.6374 Time: 35.16s
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.7517195105552673
# Micro Accuracy 0.7200000286102295
# Macro Accuracy 0.6374269127845764
# Macro Precision 0.6300942301750183
# Macro Recall 0.6374269127845764
# Macro F1 0.6374269127845764
#
#
# Training complete in 35m 18s
# Best test main metric: 0.749513

# %%
BEST_MODEL_PATH = './trained_models/{}/{}/best_model.pth'.format(MODEL_NAME, EXPERIMENT_NAME)
os.makedirs(os.path.dirname(BEST_MODEL_PATH), exist_ok=True)
torch.save(model.state_dict(), BEST_MODEL_PATH)

# %% [markdown]
# ## Evaluación final

# %%
from dataset_modules.common import pil_loader
model.load_state_dict(torch.load(BEST_MODEL_PATH))
model.eval()

metrics = metrics_helper.init_metrics(device, NUM_CLASSES)
tensorboard_transforms = transforms.Compose([
    transforms.ToTensor()
])

total_loss = 0.0

for i, (images, labels, imgs_path) in enumerate(test_loader):
    images = images.to(device)
    labels = labels.to(device)
    
    with torch.no_grad():
        outputs = model(images)
        metrics(outputs, labels)
        
        predictions = torch.argmax(outputs, dim=1)
        loss = criterion(outputs, labels)
        
        total_loss += loss.item() * images.size(0)
        
        for sampleno in range(images.shape[0]):
            if(labels[sampleno] != predictions[sampleno]):
                name = 'Misclasified_Predicted-{}_Classified-{}/{}'.format(classes[predictions[sampleno]], classes[labels[sampleno]], imgs_path[sampleno])
                
                writer.add_image(name, tensorboard_transforms(pil_loader('./dataset_modules/imgs/' + imgs_path[sampleno])))
                writer.flush()
        
total_loss /= dataset_sizes["test"]

metrics_result = metrics.compute()

# %%
macro_metrics = metrics_helper.generate_macro_metrics(metrics_result, total_loss)
per_class_metrics = metrics_helper.generate_per_class_metrics(metrics_result, classes)

macro_metrics.to_csv('./trained_models/{}/{}/best_model_macro_metrics.csv'.format(MODEL_NAME, EXPERIMENT_NAME), index=False)
per_class_metrics.to_csv('./trained_models/{}/{}/best_model_per_class_metrics.csv'.format(MODEL_NAME, EXPERIMENT_NAME), index=False)
# Out:
# ------------------------- GENERAL METRICS -------------------------
#
# Loss 0.582285925745964
# Micro Accuracy 0.7900000214576721
# Macro Accuracy 0.7030539512634277
# Macro Precision 0.7194400429725647
# Macro Recall 0.7030539512634277
# Macro F1 0.7030539512634277
#
# ------------------------- PER CLASS METRICS -------------------------
#                       class  accuracy  precision    recall        f1
# 0  paragolpe_delantero_roto  0.814815   0.594595  0.814815  0.814815
# 1  paragolpe_delantero_sano  0.368421   0.583333  0.368421  0.368421
# 2    no_paragolpe_delantero  0.925926   0.980392  0.925926  0.925926

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

df_cm = pd.DataFrame(metrics_result['confusion_matrix'], index = classes,
                  columns = classes)

df_cm = df_cm.applymap(lambda x: x.item())

plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap="Blues")
df_cm.to_csv('./trained_models/{}/{}/confusion_matrix.csv'.format(MODEL_NAME, EXPERIMENT_NAME))
